# %% [markdown]
# # Notebook para o PAN - Atribuição Autoral - 2018

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /anaconda3/lib/python3.6/site-packages (2.0.16)
# Requirement already satisfied: numpy>=1.15.0 in /anaconda3/lib/python3.6/site-packages (from spacy) (1.15.4)
# Requirement already satisfied: msgpack-numpy<0.4.4 in /anaconda3/lib/python3.6/site-packages (from spacy) (0.4.3.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /anaconda3/lib/python3.6/site-packages (from spacy) (1.0.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /anaconda3/lib/python3.6/site-packages (from spacy) (2.0.2)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /anaconda3/lib/python3.6/site-packages (from spacy) (2.0.1)
# Requirement already satisfied: thinc<6.13.0,>=6.12.0 in /anaconda3/lib/python3.6/site-packages (from spacy) (6.12.1)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /anaconda3/lib/python3.6/site-packages (from spacy) (0.9.6)
# Requirement already satisfied: ujson>=1.35 in /anaconda3/lib/python3.6/site-packages (from spacy) (1.35)
# Requirement already satisfied: dill<0.3,>=0.2 in /anaconda3/lib/python3.6/site-packages (from spacy) (0.2.8.2)
# Collecting regex==2018.01.10 (from spacy)
#   Using cached https://files.pythonhosted.org/packages/76/f4/7146c3812f96fcaaf2d06ff6862582302626a59011ccb6f2833bb38d80f7/regex-2018.01.10.tar.gz
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /anaconda3/lib/python3.6/site-packages (from spacy) (2.21.0)
# Requirement already satisfied: msgpack>=0.3.0 in /anaconda3/lib/python3.6/site-packages (from msgpack-numpy<0.4.4->spacy) (0.6.1)
# Requirement already satisfied: cytoolz<0.10,>=0.9.0 in /anaconda3/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.0->spacy) (0.9.0.1)
# Requirement already satisfied: wrapt<1.11.0,>=1.10.0 in /anaconda3/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.0->spacy) (1.10.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /anaconda3/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.0->spacy) (4.29.1)
# Requirement already satisfied: six<2.0.0,>=1.10.0 in /anaconda3/lib/python3.6/site-packages (from thinc<6.13.0,>=6.12.0->spacy) (1.12.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2018.11.29)
# Requirement already satisfied: toolz>=0.8.0 in /anaconda3/lib/python3.6/site-packages (from cytoolz<0.10,>=0.9.0->thinc<6.13.0,>=6.12.0->spacy) (0.9.0)
# Building wheels for collected packages: regex
#   Building wheel for regex (setup.py) ... error
#   Complete output from command /anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/w4/5hrb09795hx2z0_yw6r0sg780000gn/T/pip-install-b0ncj_5c/regex/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d /private/var/folders/w4/5hrb09795hx2z0_yw6r0sg780000gn/T/pip-wheel-u9k3axmz --python-tag cp36:
#   /anaconda3/lib/python3.6/site-packages/setuptools/dist.py:475: UserWarning: Normalizing '2018.01.10' to '2018.1.10'
#     normalized_version,
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.7-x86_64-3.6
#   copying regex_3/regex.py -> build/lib.macosx-10.7-x86_64-3.6
#   copying regex_3/_regex_core.py -> build/lib.macosx-10.7-x86_64-3.6
#   copying regex_3/test_regex.py -> build/lib.macosx-10.7-x86_64-3.6
#   running build_ext
#   building '_regex' extension
#   creating build/temp.macosx-10.7-x86_64-3.6
#   creating build/temp.macosx-10.7-x86_64-3.6/regex_3
#   gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -I/anaconda3/include/python3.6m -c regex_3/_regex.c -o build/temp.macosx-10.7-x86_64-3.6/regex_3/_regex.o
#   xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#   error: command 'gcc' failed with exit status 1
#
#   ----------------------------------------
#   Failed building wheel for regex
#   Running setup.py clean for regex
# Failed to build regex
# Installing collected packages: regex
#   Found existing installation: regex 2018.11.22
#     Uninstalling regex-2018.11.22:
#       Successfully uninstalled regex-2018.11.22
#   Running setup.py install for regex ... error
#     Complete output from command /anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/w4/5hrb09795hx2z0_yw6r0sg780000gn/T/pip-install-b0ncj_5c/regex/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /private/var/folders/w4/5hrb09795hx2z0_yw6r0sg780000gn/T/pip-record-c021egqb/install-record.txt --single-version-externally-managed --compile:
#     /anaconda3/lib/python3.6/site-packages/setuptools/dist.py:475: UserWarning: Normalizing '2018.01.10' to '2018.1.10'
#       normalized_version,
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.7-x86_64-3.6
#     copying regex_3/regex.py -> build/lib.macosx-10.7-x86_64-3.6
#     copying regex_3/_regex_core.py -> build/lib.macosx-10.7-x86_64-3.6
#     copying regex_3/test_regex.py -> build/lib.macosx-10.7-x86_64-3.6
#     running build_ext
#     building '_regex' extension
#     creating build/temp.macosx-10.7-x86_64-3.6
#     creating build/temp.macosx-10.7-x86_64-3.6/regex_3
#     gcc -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -g -fwrapv -O3 -Wall -Wstrict-prototypes -I/anaconda3/include -arch x86_64 -I/anaconda3/include -arch x86_64 -I/anaconda3/include/python3.6m -c regex_3/_regex.c -o build/temp.macosx-10.7-x86_64-3.6/regex_3/_regex.o
#     xcrun: error: invalid active developer path (/Library/Developer/CommandLineTools), missing xcrun at: /Library/Developer/CommandLineTools/usr/bin/xcrun
#     error: command 'gcc' failed with exit status 1
#
#     ----------------------------------------
#   Rolling back uninstall of regex
# Command "/anaconda3/bin/python -u -c "import setuptools, tokenize;__file__='/private/var/folders/w4/5hrb09795hx2z0_yw6r0sg780000gn/T/pip-install-b0ncj_5c/regex/setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record /private/var/folders/w4/5hrb09795hx2z0_yw6r0sg780000gn/T/pip-record-c021egqb/install-record.txt --single-version-externally-managed --compile" failed with error code 1 in /private/var/folders/w4/5hrb09795hx2z0_yw6r0sg780000gn/T/pip-install-b0ncj_5c/regex/

# %%
# !python -m spacy download pt
# !python -m spacy download en
# !python -m spacy download es
# !python -m spacy download de
# !python -m spacy download fr
# !python -m spacy download it
# Out:
# Requirement already satisfied: pt_core_news_sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-2.0.0/pt_core_news_sm-2.0.0.tar.gz#egg=pt_core_news_sm==2.0.0 in /anaconda3/lib/python3.6/site-packages (2.0.0)
#
#     Linking successful
#     /anaconda3/lib/python3.6/site-packages/pt_core_news_sm -->
#     /anaconda3/lib/python3.6/site-packages/spacy/data/pt
#
#     You can now load the model via spacy.load('pt')
#
# Requirement already satisfied: en_core_web_sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.0.0/en_core_web_sm-2.0.0.tar.gz#egg=en_core_web_sm==2.0.0 in /anaconda3/lib/python3.6/site-packages (2.0.0)
#
#     Linking successful
#     /anaconda3/lib/python3.6/site-packages/en_core_web_sm -->
#     /anaconda3/lib/python3.6/site-packages/spacy/data/en
#
#     You can now load the model via spacy.load('en')
#
# Requirement already satisfied: es_core_news_sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-2.0.0/es_core_news_sm-2.0.0.tar.gz#egg=es_core_news_sm==2.0.0 in /anaconda3/lib/python3.6/site-packages (2.0.0)
#
#     Linking successful
#     /anaconda3/lib/python3.6/site-packages/es_core_news_sm -->
#     /anaconda3/lib/python3.6/site-packages/spacy/data/es
#
#     You can now load the model via spacy.load('es')
#
# Requirement already satisfied: de_core_news_sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-2.0.0/de_core_news_sm-2.0.0.tar.gz#egg=de_core_news_sm==2.0.0 in /anaconda3/lib/python3.6/site-packages (2.0.0)
#
#     Linking successful
#     /anaconda3/lib/python3.6/site-packages/de_core_news_sm -->
#     /anaconda3/lib/python3.6/site-packages/spacy/data/de
#
#     You can now load the model via spacy.load('de')
#
# Requirement already satisfied: fr_core_news_sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-2.0.0/fr_core_news_sm-2.0.0.tar.gz#egg=fr_core_news_sm==2.0.0 in /anaconda3/lib/python3.6/site-packages (2.0.0)
#
#     Linking successful
#     /anaconda3/lib/python3.6/site-packages/fr_core_news_sm -->
#     /anaconda3/lib/python3.6/site-packages/spacy/data/fr
#
#     You can now load the model via spacy.load('fr')
#
# Requirement already satisfied: it_core_news_sm==2.0.0 from https://github.com/explosion/spacy-models/releases/download/it_core_news_sm-2.0.0/it_core_news_sm-2.0.0.tar.gz#egg=it_core_news_sm==2.0.0 in /anaconda3/lib/python3.6/site-packages (2.0.0)
#
#     Linking successful
#     /anaconda3/lib/python3.6/site-packages/it_core_news_sm -->
#     /anaconda3/lib/python3.6/site-packages/spacy/data/it
#
#     You can now load the model via spacy.load('it')

# %%
# %matplotlib inline
#python basic libs
import os;
from os.path import join as pathjoin;

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from sklearn.exceptions import UndefinedMetricWarning
warnings.simplefilter(action='ignore', category=UndefinedMetricWarning)

import re;
import glob;
import json;
import codecs;
from collections import defaultdict;
import pprint;


from pprint import pprint
from time import time
import logging


#data analysis libs
import numpy as np;
import pandas as pd;
from pandas.plotting import scatter_matrix;
import matplotlib.pyplot as plt;
import random;

#machine learning libs
#feature extraction
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer

#preprocessing and transformation
from sklearn.preprocessing import normalize, MaxAbsScaler, MinMaxScaler, Normalizer, RobustScaler;
from sklearn.preprocessing import LabelBinarizer;
from sklearn.decomposition import PCA;
from sklearn.metrics.pairwise import cosine_similarity;


from sklearn.base import BaseEstimator, ClassifierMixin

#classifiers
from sklearn.svm import LinearSVC, SVC
from sklearn.multiclass import OneVsOneClassifier, OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier

from sklearn.feature_selection import RFE,SelectFpr,SelectPercentile, chi2;

#
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, VotingClassifier

from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

#model valuation
from sklearn.model_selection import train_test_split;
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score, accuracy_score;

# %%
import seaborn as sns;
sns.set(color_codes=True);

# %%
import platform;
import sklearn;
import scipy;
import spacy;

print("|%-15s|%-40s|"%("PACK","VERSION"))
print("|%-15s|%-40s|"%('-'*15,'-'*40))
print('\n'.join(
    "|%-15s|%-40s|" % (pack, version)
    for pack, version in
    zip(['SO','NumPy','SciPy','Scikit-Learn','seaborn','spacy'],
        [platform.platform(), np.__version__, scipy.__version__, sklearn.__version__, sns.__version__, spacy.__version__])

))
# Out:
# |PACK           |VERSION                                 |
# |---------------|----------------------------------------|
# |SO             |Darwin-18.2.0-x86_64-i386-64bit         |
# |NumPy          |1.15.4                                  |
# |SciPy          |1.1.0                                   |
# |Scikit-Learn   |0.20.1                                  |
# |seaborn        |0.9.0                                   |
# |spacy          |2.0.16                                  |

# %%
np.set_printoptions(precision=4)
pd.options.display.float_format = '{:,.4f}'.format

# %% [markdown]
# ### paths configuration

# %% [markdown]
# ### on google

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
# !ls '/gdrive/My Drive/data_repository'
# Out:
# banking.csv.gz	out  pan18aa  Sentiment.csv.zip

# %%
baseDir = '/gdrive/My Drive/data_repository';
modelName = 'char1';

inputDir= pathjoin(baseDir,'pan18aa');
outputDir= pathjoin(baseDir,'out',modelName);

os.makedirs(outputDir, exist_ok=True)

# %%
def transferCode(filename):
    with open(os.path.join('/gdrive/My Drive','Colab Notebooks',filename)) as fin:
        with open(filename,'w') as fout:
            fout.write(fin.read());

# %%
transferCode('pan.py')
transferCode('sklearnExtensions.py')

# %%
# !ls
# Out:
# pan.py	sample_data  sklearnExtensions.py

# %%
### on local

# %%
baseDir = '/Users/joseeleandrocustodio/dataScienceNotebook/PANAA2018';

corpusTraining    = 'pan18-cross-domain-authorship-attribution-training-dataset-2017-12-02';
corpusEvaluation = 'pan18-cross-domain-authorship-attribution-test-dataset2-2018-04-20';

inputDir= pathjoin(baseDir,corpusTraining);
outputDir= pathjoin(baseDir,'out');
if not os.path.exists(outputDir):
    os.mkdir(outputDir);

# %% [markdown]
# ## Data Ingestion

# %%
import pan
import sklearnExtensions
from sklearnExtensions import DenseTransformer
from sklearnExtensions import POSTagTransformer

# %%
problems = pan.readCollectionsOfProblems(inputDir);

# %%
pd.DataFrame(problems)
# Out:
#                                           candidates  candidates_folder_count  \
# 0  [[graceful ones.\n\n"One more," Marvelous said...                       20
# 1  [[a mission."\n\nJensen just raises an eyebrow...                        5
# 2  [[qui l'avait tué mais tout était de la faute ...                       20
# 3  [[. Le canapé est vide et lorsqu'il passe deva...                        5
# 4  [[Eppure lui la mappa l’aveva stampata, dannaz...                       20
# 5  [[Yato ha trovato una lettera sul suo comodino...                        5
# 6  [[zmienił zdanie. Niech się stworzonko pobawi....                       20
# 7  [[Słowem, które Sherlock najczęściej słyszał w...                        5
# 8  [[pero no lo ama como ama a Guignol –explicó e...                       20
# 9  [[incapaz de señalar un momento exacto, un pun...                        5
#
#   encoding language       problem  \
# 0    UTF-8       en  problem00001
# 1    UTF-8       en  problem00002
# 2    UTF-8       fr  problem00003
# 3    UTF-8       fr  problem00004
# 4    UTF-8       it  problem00005
# 5    UTF-8       it  problem00006
# 6    UTF-8       pl  problem00007
# 7    UTF-8       pl  problem00008
# 8    UTF-8       sp  problem00009
# 9    UTF-8       sp  problem00010
#
#                                              unknown
# 0  [[after all, his best friends. And what in the...
# 1  [[“Potter was attractive,” Draco thought, sigh...
# 2  [[son réveil. Sa main pulse et Draco frotte l'...
# 3  [[abasourdie.\n\nTout d'abord, elle crut que s...
# 4  [[– Oh. Cazzo.\nSirius era così sconvolto che ...
# 5  [[così la tua vista, Moony?\n– Cercavo di esse...
# 6  [[dawniej pełna radości i ciepła, a teraz wiec...
# 7  [[, uderzającego o żebra niczym dzwon- niemal ...
# 8  [[–La nariz puntiaguda del elfo casi rozaba el...
# 9  [[tan parecidas hizo que su trasero latiese de...

# %%
def cachingPOSTAG(problem, corpusName, taggingVersion='TAG',verbose=False):
    import json;
    if verbose:
        print ("Tagging: %s,  language: %s, " %(problem['problem'],problem['language']), end=' ');
    
    pos_cache_dir = pathjoin('POSTAG_cache',corpusName);
    
    if not os.path.exists(pos_cache_dir):
        os.makedirs(pos_cache_dir);
    
    _id = problem['problem']+problem['language'];
    filename = os.path.join(pos_cache_dir,taggingVersion+'_'+_id+'.json')
    if not os.path.exists(filename):
        lang = problem['language'];
        if lang == 'sp':
            lang = 'es';
        elif lang =='pl':
            print(lang, ' not supported');
            return ;

        train_docs, train_labels, _   = zip(*problem['candidates'])
        problem['training_docs_size'] = len(train_docs);
        test_docs, _, test_filename   = zip(*problem['unknown'])

        t0 = time()
        tagger = POSTagTransformer(language=lang);
        train_docs = tagger.fit_transform(train_docs);
        test_docs = tagger.fit_transform(test_docs);
        
        print("Annotation time %0.3fs" % (time() - t0))
        
        with open(filename,'w') as f:
            json.dump({
                'train':train_docs,
                'train_labels':train_labels,
                'test':test_docs,
                'test_filename':test_filename
            },f);
    else:
        with open(filename,'r') as f:
            data = json.load(f);

            train_docs = data['train'];
            train_labels = data['train_labels'];
            test_docs  = data['test'];
            test_filename = data['test_filename'];
    if verbose:
        print('tagged')
    return train_docs, train_labels, test_docs, test_filename;

for problem in problems:
    cachingPOSTAG(problem,corpusTraining,verbose=True)
# Out:
# Tagging: problem00001,  language: en,  tagged
# Tagging: problem00002,  language: en,  tagged
# Tagging: problem00003,  language: fr,  tagged
# Tagging: problem00004,  language: fr,  tagged
# Tagging: problem00005,  language: it,  tagged
# Tagging: problem00006,  language: it,  tagged
# Tagging: problem00007,  language: pl,  pl  not supported
# Tagging: problem00008,  language: pl,  pl  not supported
# Tagging: problem00009,  language: sp,  tagged
# Tagging: problem00010,  language: sp,  tagged

# %%
from sklearnExtensions import POSTagTransformer, FilterTagTransformer

# %%
def  listTag(problem):
    print ("\nProblem: %s,  language: %s, " %(problem['problem'],problem['language']), end=' ');
    
    lang = problem['language'];
    if lang == 'sp':
        lang = 'es';
    elif lang =='pl':
        print(lang, ' not supported');
        return None;
    
    
    train_docs, train_labels, test_docs, test_filename = cachingPOSTAG(problem,corpusName=corpusTraining)
    
    detectedPOS = sorted(set([d[2] for doc in train_docs for d in doc if d[2] not in ['','SPACE','SYM']]))
    
    print("Detected POS: \n"+ str(detectedPOS));
for problem in problems:
    listTag(problem)
# Out:
# Problem: problem00001,  language: en,  Detected POS:
# ['ADJ', 'ADP', 'ADV', 'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART', 'PRON', 'PROPN', 'PUNCT', 'VERB', 'X']
#
# Problem: problem00002,  language: en,  Detected POS:
# ['ADJ', 'ADP', 'ADV', 'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART', 'PRON', 'PROPN', 'PUNCT', 'VERB', 'X']
#
# Problem: problem00003,  language: fr,  Detected POS:
# ['ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART', 'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'VERB', 'X']
#
# Problem: problem00004,  language: fr,  Detected POS:
# ['ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'VERB', 'X']
#
# Problem: problem00005,  language: it,  Detected POS:
# ['ADJ', 'ADP', 'ADV', 'AUX', 'CONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART', 'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'VERB', 'X']
#
# Problem: problem00006,  language: it,  Detected POS:
# ['ADJ', 'ADP', 'ADV', 'AUX', 'CONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'VERB', 'X']
#
# Problem: problem00007,  language: pl,  pl  not supported
#
# Problem: problem00008,  language: pl,  pl  not supported
#
# Problem: problem00009,  language: sp,  Detected POS:
# ['ADJ', 'ADP', 'ADV', 'AUX', 'CONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART', 'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'VERB', 'X']
#
# Problem: problem00010,  language: sp,  Detected POS:
# ['ADJ', 'ADP', 'ADV', 'AUX', 'CONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART', 'PRON', 'PROPN', 'PUNCT', 'SCONJ', 'VERB']

# %%
def countFeatures(taggedDocs,min_df,ngram_range=(2,5)):
    detectedPOS = sorted(set([d[2] for doc in taggedDocs for d in doc]));
    counts = [];
    
    for p in detectedPOS:
        pipeline = Pipeline([
                  ('filter',FilterTagTransformer(token='filter',parts=[p])),
                  ('vect', CountVectorizer(
                  analyzer='word',
                  ngram_range=ngram_range,
                  lowercase=False
                  ))
                 ]);
        try:
            validFeatures = np.sum(np.mean(pipeline.fit_transform(taggedDocs)>0, axis=0) > min_df);
        except ValueError:
            validFeatures =0;
        counts.append(validFeatures);
            
    return zip(detectedPOS,counts);

# %%
def runEachPOS(problem):
    print ("\nProblem: %s,  language: %s, " %(problem['problem'],problem['language']), end=' ');
    
    lang = problem['language'];
    if lang == 'sp':
        lang = 'es';
    elif lang =='pl':
        print(lang, ' not supported');
        return None,None;
    
    
    train_docs, train_labels, test_docs, test_filename = cachingPOSTAG(problem,corpusTraining)
    
    detectedPOS = countFeatures(train_docs,0.01,(1,5));
    
    POS = [p[0] for p in detectedPOS if p[1] > 100];
    print("Detected POS: "+ str(POS));
    
    t0 = time()
    
    pipeline = Pipeline([
        ('filter',FilterTagTransformer(token='filter')),
        ('vect', CountVectorizer(
                                   analyzer='word',
                                   ngram_range=(1,3),
                                   min_df=0.01,
                                   lowercase=False
                                  )),
        ('tfidf',  TfidfTransformer(norm='l2',sublinear_tf=True)),
        ('scaler', MaxAbsScaler()),
        ('dense',  DenseTransformer()),
        ('transf', PCA(0.999)),
        ('clf', LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
    ])
    
    
    # uncommenting more parameters will give better exploring power but will
    # increase processing time in a combinatorial way
    parameters = {
        'filter__parts':POS
    }
    
    grid_search = GridSearchCV(pipeline,
                               parameters,
                               cv=5,
                               iid=False,
                               n_jobs=-1,
                               verbose=True,
                               scoring='f1_macro')
    
    t0 = time()
    grid_search.fit(train_docs, train_labels)
    
    print("Gridsearh %0.3fs" % (time() - t0), end=' ')

    print("Best score: %0.3f" % grid_search.best_score_)
    print("Best parameters set:")
    best_parameters = grid_search.best_estimator_.get_params()
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))
        
    train_pred=grid_search.predict(train_docs);
    test_pred=grid_search.predict(test_docs);
    
    
    # Writing output file
    out_data=[]
    for i,v in enumerate(test_pred):
        out_data.append({'unknown-text': test_filename[i],'predicted-author': v})
    answerFile = pathjoin(outputDir,'answers-'+problem['problem']+'.json');
    with open(answerFile, 'w') as f:
        json.dump(out_data, f, indent=4)
    
    
    #calculating the performance using PAN evaluation code
    f1,precision,recall,accuracy=pan.evaluate(
                pathjoin(inputDir, problem['problem'], 'ground-truth.json'),
                answerFile)
    
    return  {
                'problem-name'  :   problem['problem'],
                "language"      :  problem['language'],
                'AuthorCount'   :  len(set(train_labels)),
                'macro-f1'       : round(f1,3),
                'macro-precision': round(precision,3),
                'macro-recall'   : round(recall,3),
                'micro-accuracy' : round(accuracy,3),
                
        },grid_search.cv_results_;

# %%
cv_result = [];
result = [];
for problem in problems:
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore");
        r,c = runEachPOS(problem);
        cv_result.append(c);
        result.append(r);
# Out:
# Problem: problem00001,  language: en,  Detected POS: ['ADJ', 'ADP', 'ADV', 'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART', 'PRON', 'PROPN', 'VERB']
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  2.6min finished
# Gridsearh 153.858s Best score: 0.381
# Best parameters set:
# 	filter__parts: 'PROPN'
#
# Problem: problem00002,  language: en,  Detected POS: ['ADJ', 'ADP', 'ADV', 'CCONJ', 'DET', 'INTJ', 'NOUN', 'NUM', 'PART', 'PRON', 'PROPN', 'VERB']
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   26.7s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   37.7s finished
# Gridsearh 37.794s Best score: 0.521
# Best parameters set:
# 	filter__parts: 'ADV'
#
# Problem: problem00003,  language: fr,  Detected POS: ['ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET', 'NOUN', 'PRON', 'PROPN', 'SCONJ', 'VERB']
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:  2.4min finished
# Gridsearh 145.617s Best score: 0.438
# Best parameters set:
# 	filter__parts: 'NOUN'
#
# Problem: problem00004,  language: fr,  Detected POS: ['ADJ', 'ADP', 'ADV', 'AUX', 'CCONJ', 'DET', 'NOUN', 'NUM', 'PRON', 'PROPN', 'SCONJ', 'VERB']
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   38.6s finished
# Gridsearh 38.658s Best score: 0.808
# Best parameters set:
# 	filter__parts: 'NOUN'
#
# Problem: problem00005,  language: it,  Detected POS: ['ADJ', 'ADP', 'ADV', 'AUX', 'CONJ', 'DET', 'NOUN', 'PRON', 'PROPN', 'SCONJ', 'VERB']
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:  2.4min finished
# Gridsearh 147.156s Best score: 0.360
# Best parameters set:
# 	filter__parts: 'NOUN'
#
# Problem: problem00006,  language: it,  Detected POS: ['ADJ', 'ADP', 'ADV', 'AUX', 'CONJ', 'DET', 'NOUN', 'NUM', 'PRON', 'PROPN', 'SCONJ', 'VERB']
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   31.8s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   42.5s finished
# Gridsearh 42.528s Best score: 0.552
# Best parameters set:
# 	filter__parts: 'VERB'
#
# Problem: problem00007,  language: pl,  pl  not supported
#
# Problem: problem00008,  language: pl,  pl  not supported
#
# Problem: problem00009,  language: sp,  Detected POS: ['ADJ', 'ADP', 'ADV', 'AUX', 'CONJ', 'DET', 'NOUN', 'PRON', 'PROPN', 'SCONJ', 'VERB']
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.9min
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:  2.5min finished
# Gridsearh 150.099s Best score: 0.512
# Best parameters set:
# 	filter__parts: 'NOUN'
#
# Problem: problem00010,  language: sp,  Detected POS: ['ADJ', 'ADP', 'ADV', 'AUX', 'CONJ', 'DET', 'NOUN', 'NUM', 'PRON', 'PROPN', 'SCONJ', 'VERB']
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:   27.2s
# Gridsearh 38.447s Best score: 0.907
# Best parameters set:
# 	filter__parts: 'PROPN'
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:   38.4s finished

# %%
languages={
    'en':'inglesa',
    'sp':'espanhola',
    'it':'italiana',
    'pl':'polonesa',
    'fr':'francesa'
}

# %%
cv_result_parts = cv_result;
dfParts = pd.DataFrame();
for i, c in enumerate(cv_result_parts):
    if c is None:
        continue;
    temp = pd.DataFrame(c);
    temp['problem'] = int(re.sub('\D','',result[i]['problem-name']));
    temp['f1best']  = result[i]['macro-f1'];
    temp['language'] = languages[result[i]['language']];
    dfParts = dfParts.append(temp);

for p in [
    'mean_test_score','std_test_score','mean_train_score',   
    'split0_test_score',
    'split1_test_score',
    'split2_test_score']:
    dfParts[p]=dfParts[p].astype(np.float32);

    
dfParts =dfParts[[
    'problem',
    'language',
    'f1best',
    'rank_test_score',
    'param_filter__parts',
    'mean_test_score',   
    'std_test_score',
    'mean_score_time',
    'mean_fit_time',
    'std_fit_time',
    'std_score_time',
    'std_train_score',
]];

dfParts.rename(columns={
    'param_filter__parts':'POSFILTER',
},inplace=True);

#print('\',\n\''.join(dfCV.columns))

# %%
dfParts.sort_values(['problem', 'rank_test_score'], inplace=True)
dfParts
# Out:
#     problem   language  f1best  rank_test_score POSFILTER  mean_test_score  \
# 10        1    inglesa  0.0200                1     PROPN           0.3811
# 11        1    inglesa  0.0200                2      VERB           0.2529
# 6         1    inglesa  0.0200                3      NOUN           0.2421
# 0         1    inglesa  0.0200                4       ADJ           0.2074
# 2         1    inglesa  0.0200                5       ADV           0.2034
# 9         1    inglesa  0.0200                6      PRON           0.1465
# 1         1    inglesa  0.0200                7       ADP           0.1238
# 5         1    inglesa  0.0200                8      INTJ           0.1165
# 7         1    inglesa  0.0200                9       NUM           0.0834
# 4         1    inglesa  0.0200               10       DET           0.0807
# 3         1    inglesa  0.0200               11     CCONJ           0.0425
# 8         1    inglesa  0.0200               12      PART           0.0216
# 2         2    inglesa  0.2020                1       ADV           0.5213
# 0         2    inglesa  0.2020                2       ADJ           0.4842
# 11        2    inglesa  0.2020                3      VERB           0.4800
# 6         2    inglesa  0.2020                4      NOUN           0.4495
# 9         2    inglesa  0.2020                5      PRON           0.3920
# 5         2    inglesa  0.2020                6      INTJ           0.3707
# 10        2    inglesa  0.2020                7     PROPN           0.3646
# 7         2    inglesa  0.2020                8       NUM           0.3400
# 1         2    inglesa  0.2020                9       ADP           0.3347
# 3         2    inglesa  0.2020               10     CCONJ           0.2215
# 8         2    inglesa  0.2020               11      PART           0.1760
# 4         2    inglesa  0.2020               12       DET           0.1627
# 6         3   francesa  0.1940                1      NOUN           0.4377
# 10        3   francesa  0.1940                2      VERB           0.3740
# 8         3   francesa  0.1940                3     PROPN           0.3094
# 2         3   francesa  0.1940                4       ADV           0.2511
# 7         3   francesa  0.1940                5      PRON           0.2096
# 0         3   francesa  0.1940                6       ADJ           0.1771
# ..      ...        ...     ...              ...       ...              ...
# 0         6   italiana  0.4070                6       ADJ           0.3560
# 10        6   italiana  0.4070                7     SCONJ           0.3074
# 8         6   italiana  0.4070                8      PRON           0.2920
# 3         6   italiana  0.4070                9       AUX           0.2813
# 1         6   italiana  0.4070               10       ADP           0.2333
# 7         6   italiana  0.4070               11       NUM           0.2320
# 4         6   italiana  0.4070               12      CONJ           0.2280
# 6         9  espanhola  0.3360                1      NOUN           0.5117
# 8         9  espanhola  0.3360                2     PROPN           0.5085
# 10        9  espanhola  0.3360                3      VERB           0.3859
# 2         9  espanhola  0.3360                4       ADV           0.3010
# 0         9  espanhola  0.3360                5       ADJ           0.2958
# 7         9  espanhola  0.3360                6      PRON           0.2237
# 9         9  espanhola  0.3360                7     SCONJ           0.1499
# 3         9  espanhola  0.3360                8       AUX           0.1352
# 5         9  espanhola  0.3360                9       DET           0.1309
# 1         9  espanhola  0.3360               10       ADP           0.1199
# 4         9  espanhola  0.3360               11      CONJ           0.0696
# 9        10  espanhola  0.1990                1     PROPN           0.9067
# 6        10  espanhola  0.1990                2      NOUN           0.6240
# 11       10  espanhola  0.1990                3      VERB           0.4793
# 2        10  espanhola  0.1990                4       ADV           0.4322
# 0        10  espanhola  0.1990                5       ADJ           0.3804
# 8        10  espanhola  0.1990                6      PRON           0.3747
# 5        10  espanhola  0.1990                7       DET           0.3560
# 10       10  espanhola  0.1990                8     SCONJ           0.2813
# 1        10  espanhola  0.1990                9       ADP           0.2293
# 7        10  espanhola  0.1990               10       NUM           0.2160
# 3        10  espanhola  0.1990               11       AUX           0.1989
# 4        10  espanhola  0.1990               12      CONJ           0.1987
#
#     std_test_score  mean_score_time  mean_fit_time  std_fit_time  \
# 10          0.0774           0.0119         0.0922        0.0371
# 11          0.0626           0.0400         0.4769        0.2687
# 6           0.0755           0.0243         0.2989        0.1555
# 0           0.0666           0.0164         0.1485        0.0569
# 2           0.0639           0.0136         0.1448        0.0585
# 9           0.0702           0.0113         0.0777        0.0115
# 1           0.0254           0.0143         0.1217        0.0371
# 5           0.0548           0.0109         0.0403        0.0117
# 7           0.0537           0.0051         0.0299        0.0017
# 4           0.0573           0.0077         0.0513        0.0029
# 3           0.0287           0.0095         0.0561        0.0225
# 8           0.0276           0.0073         0.0398        0.0075
# 2           0.2243           0.0036         0.0257        0.0021
# 0           0.1589           0.0039         0.0327        0.0020
# 11          0.1354           0.0067         0.0579        0.0065
# 6           0.1630           0.0054         0.0479        0.0105
# 9           0.0879           0.0031         0.0195        0.0011
# 5           0.2073           0.0024         0.0123        0.0005
# 10          0.1679           0.0027         0.0176        0.0020
# 7           0.2768           0.0020         0.0114        0.0005
# 1           0.1935           0.0041         0.0266        0.0043
# 3           0.0787           0.0027         0.0172        0.0058
# 8           0.0760           0.0025         0.0131        0.0006
# 4           0.1217           0.0030         0.0170        0.0008
# 6           0.1351           0.0373         0.3903        0.2335
# 10          0.1380           0.0588         0.3298        0.1692
# 8           0.0583           0.0086         0.0692        0.0125
# 2           0.0674           0.0125         0.1251        0.0119
# 7           0.0649           0.0143         0.1147        0.0235
# 0           0.0515           0.0130         0.1261        0.0466
# ..             ...              ...            ...           ...
# 0           0.0597           0.0039         0.0276        0.0049
# 10          0.1949           0.0026         0.0151        0.0007
# 8           0.1429           0.0035         0.0263        0.0099
# 3           0.1525           0.0026         0.0163        0.0013
# 1           0.1491           0.0032         0.0190        0.0016
# 7           0.1944           0.0020         0.0112        0.0008
# 4           0.1205           0.0021         0.0113        0.0005
# 6           0.0202           0.0292         0.3754        0.2002
# 8           0.1040           0.0095         0.0849        0.0340
# 10          0.1088           0.0248         0.3433        0.1962
# 2           0.0731           0.0116         0.1052        0.0308
# 0           0.0603           0.0133         0.1374        0.0490
# 7           0.0810           0.0115         0.0888        0.0150
# 9           0.0758           0.0074         0.0482        0.0021
# 3           0.0638           0.0108         0.0878        0.0192
# 5           0.0382           0.0139         0.1104        0.0212
# 1           0.0382           0.0115         0.0720        0.0140
# 4           0.0355           0.0051         0.0304        0.0032
# 9           0.1162           0.0027         0.0186        0.0018
# 6           0.2048           0.0059         0.0604        0.0152
# 11          0.1531           0.0056         0.0449        0.0035
# 2           0.1615           0.0044         0.0313        0.0032
# 0           0.1807           0.0036         0.0283        0.0023
# 8           0.1981           0.0033         0.0236        0.0038
# 5           0.1104           0.0042         0.0266        0.0029
# 10          0.1799           0.0026         0.0159        0.0028
# 1           0.1090           0.0036         0.0212        0.0016
# 7           0.0709           0.0020         0.0112        0.0006
# 3           0.0366           0.0030         0.0199        0.0011
# 4           0.1230           0.0022         0.0134        0.0032
#
#     std_score_time  std_train_score
# 10          0.0060           0.0416
# 11          0.0314           0.0000
# 6           0.0172           0.0000
# 0           0.0112           0.0000
# 2           0.0076           0.0000
# 9           0.0036           0.0000
# 1           0.0079           0.0000
# 5           0.0106           0.0489
# 7           0.0017           0.0619
# 4           0.0026           0.0000
# 3           0.0062           0.0254
# 8           0.0013           0.0092
# 2           0.0007           0.0000
# 0           0.0010           0.0000
# 11          0.0022           0.0000
# 6           0.0007           0.0000
# 9           0.0006           0.0000
# 5           0.0005           0.0325
# 10          0.0005           0.0000
# 7           0.0002           0.0396
# 1           0.0008           0.0000
# 3           0.0007           0.0300
# 8           0.0004           0.0000
# 4           0.0008           0.0000
# 6           0.0310           0.0000
# 10          0.0849           0.0000
# 8           0.0033           0.0092
# 2           0.0066           0.0000
# 7           0.0063           0.0000
# 0           0.0079           0.0000
# ..             ...              ...
# 0           0.0005           0.0000
# 10          0.0004           0.0000
# 8           0.0007           0.0000
# 3           0.0004           0.0000
# 1           0.0006           0.0000
# 7           0.0003           0.0142
# 4           0.0004           0.0177
# 6           0.0222           0.0000
# 8           0.0049           0.0183
# 10          0.0177           0.0000
# 2           0.0046           0.0000
# 0           0.0088           0.0000
# 7           0.0047           0.0000
# 9           0.0024           0.0000
# 3           0.0058           0.0000
# 5           0.0057           0.0000
# 1           0.0036           0.0000
# 4           0.0011           0.0627
# 9           0.0005           0.0000
# 6           0.0009           0.0000
# 11          0.0018           0.0000
# 2           0.0007           0.0000
# 0           0.0009           0.0000
# 8           0.0007           0.0000
# 5           0.0008           0.0000
# 10          0.0003           0.0000
# 1           0.0008           0.0000
# 7           0.0003           0.0213
# 3           0.0007           0.0000
# 4           0.0005           0.0215
#
# [93 rows x 12 columns]

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True);

with pd.option_context('display.precision', 3):
    html = dfParts.pivot_table(
                index=['POSFILTER'],
                columns=['problem'],
                values=['mean_test_score']
            ).fillna(value=0).reset_index().style.background_gradient(cmap=cm,axis=1).highlight_null('#fcc')
html
# Out:
# <style  type="text/css" >
#     #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row0_col1 {
#             background-color:  #b2e3b2;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row0_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row0_col3 {
#             background-color:  #c6eec6;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row0_col4 {
#             background-color:  #69ba69;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row0_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row0_col6 {
#             background-color:  #53ae53;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row0_col7 {
#             background-color:  #7ac37a;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row0_col8 {
#             background-color:  #43a543;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row1_col1 {
#             background-color:  #c7eec7;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row1_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row1_col3 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row1_col4 {
#             background-color:  #198e19;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row1_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row1_col6 {
#             background-color:  #5fb55f;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row1_col7 {
#             background-color:  #caf0ca;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row1_col8 {
#             background-color:  #63b763;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row2_col2 {
#             background-color:  #289628;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row2_col3 {
#             background-color:  #caf0ca;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row2_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row2_col5 {
#             background-color:  #e4fee4;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row2_col6 {
#             background-color:  #50ac50;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row2_col7 {
#             background-color:  #acdfac;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row2_col8 {
#             background-color:  #5eb45e;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row3_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row3_col3 {
#             background-color:  #8cce8c;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row3_col4 {
#             background-color:  #5bb25b;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row3_col5 {
#             background-color:  #a2daa2;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row3_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row3_col7 {
#             background-color:  #77c277;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row3_col8 {
#             background-color:  #44a544;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row4_col1 {
#             background-color:  #c3ecc3;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row4_col2 {
#             background-color:  #339c33;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row4_col3 {
#             background-color:  #82c882;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row4_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row4_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row4_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row4_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row4_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row5_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row5_col3 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row5_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row5_col5 {
#             background-color:  #6cbc6c;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row5_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row5_col7 {
#             background-color:  #9fd89f;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row5_col8 {
#             background-color:  #1d901d;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row6_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row6_col2 {
#             background-color:  #ade0ad;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row6_col3 {
#             background-color:  #caf0ca;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row6_col4 {
#             background-color:  #b6e5b6;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row6_col5 {
#             background-color:  #daf9da;
#             color:  #000000;
#             : ;
#         }    #T_d05d59ee_2ec0_11e9_86ce_8c8590360b07row6_col6 {
#             background

# %%
dfParts.to_csv('PANAA2018_POSWORD_ONEPOS.csv', index=False)

# %% [markdown]
# ### analisando os demais parametros

# %%
dfParts.sort_values(['problem', 'rank_test_score'], inplace=True)
bestPOS = {};
for i,pos in zip(dfParts.problem.values,dfParts.POSFILTER.values):
    if i not in bestPOS:
        bestPOS[i] =[];
    bestPOS[i].append(pos);
    
for i in bestPOS.keys():
    print(i,'==>', bestPOS[i])
# Out:
# 1 ==> ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'PRON', 'ADP', 'INTJ', 'NUM', 'DET', 'CCONJ', 'PART']
# 2 ==> ['ADV', 'ADJ', 'VERB', 'NOUN', 'PRON', 'INTJ', 'PROPN', 'NUM', 'ADP', 'CCONJ', 'PART', 'DET']
# 3 ==> ['NOUN', 'VERB', 'PROPN', 'ADV', 'PRON', 'ADJ', 'SCONJ', 'CCONJ', 'DET', 'AUX', 'ADP']
# 4 ==> ['NOUN', 'VERB', 'ADV', 'SCONJ', 'PROPN', 'PRON', 'ADJ', 'ADP', 'CCONJ', 'AUX', 'DET', 'NUM']
# 5 ==> ['NOUN', 'VERB', 'PROPN', 'ADV', 'PRON', 'SCONJ', 'ADJ', 'CONJ', 'DET', 'ADP', 'AUX']
# 6 ==> ['VERB', 'ADV', 'NOUN', 'DET', 'PROPN', 'ADJ', 'SCONJ', 'PRON', 'AUX', 'ADP', 'NUM', 'CONJ']
# 9 ==> ['NOUN', 'PROPN', 'VERB', 'ADV', 'ADJ', 'PRON', 'SCONJ', 'AUX', 'DET', 'ADP', 'CONJ']
# 10 ==> ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP', 'NUM', 'AUX', 'CONJ']

# %%
#creating subset with best features first

for i in range(0,len(bestPOS[1])):
    print(bestPOS[1][0:(i+1)])
# Out:
# ['PROPN']
# ['PROPN', 'VERB']
# ['PROPN', 'VERB', 'NOUN']
# ['PROPN', 'VERB', 'NOUN', 'ADJ']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM', 'CCONJ']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM', 'CCONJ', 'PART']

# %%
def runML(problem, sortedPOS):
    import gc;
    gc.collect();
    print ("\nProblem: %s,  language: %s, " %(problem['problem'],problem['language']));
    
    lang = problem['language'];
    if lang == 'sp':
        lang = 'es';
    elif lang =='pl':
        print(lang, ' not supported');
        return None,None,None,None;
    
    
    train_docs, train_labels, test_docs, test_filename = cachingPOSTAG(problem)
    
    POS = [
        sortedPOS[0:(i+1)]
        for i in range(0, len(sortedPOS))
    ]
    for p in POS:
        print(p);
    
    t0 = time()
    
    pipeline = Pipeline([
        ('filter',FilterTagTransformer(token='filter')),
        ('vect', TfidfVectorizer(
                                   analyzer='word',
                                   min_df=0.01,
                                   lowercase=False,
                                    norm='l2',sublinear_tf=True)),
        ('scaler', MaxAbsScaler()),
        ('dense',  DenseTransformer()),
        ('transf', PCA(0.999)),
        ('clf', LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
    ])
    
    
    # uncommenting more parameters will give better exploring power but will
    # increase processing time in a combinatorial way
    parameters = {
        'filter__parts':POS,
        'vect__ngram_range':((2,5),(2,4),(3,5))
    }
    
    grid_search = GridSearchCV(pipeline,
                               parameters,
                               cv=3,
                               iid=False,
                               n_jobs=1,
                               verbose=True,
                               scoring='f1_macro')
    
    t0 = time()
    grid_search.fit(train_docs, train_labels)
    
    print("Gridsearh %0.3fs" % (time() - t0), end=' ')

    print("Best score: %0.3f" % grid_search.best_score_)
    print("Best parameters set:")
    best_parameters = grid_search.best_estimator_.get_params()
    for param_name in sorted(parameters.keys()):
        print("\t%s: %r" % (param_name, best_parameters[param_name]))
        
    train_pred=grid_search.predict(train_docs);
    test_pred=grid_search.predict(test_docs);
    
    
    # Writing output file
    out_data=[]
    for i,v in enumerate(test_pred):
        out_data.append({'unknown-text': test_filename[i],'predicted-author': v})
    answerFile = pathjoin(outputDir,'answers-'+problem['problem']+'.json');
    with open(answerFile, 'w') as f:
        json.dump(out_data, f, indent=4)
    
    
    #calculating the performance using PAN evaluation code
    f1,precision,recall,accuracy=pan.evaluate(
                pathjoin(inputDir, problem['problem'], 'ground-truth.json'),
                answerFile)
    
    return {
                'problem-name'  :       problem['problem'],
                "language"      :       problem['language'],
                'macro-f1'       : round(f1,3),
                'macro-precision': round(precision,3),
                'macro-recall'   : round(recall,3),
                'micro-accuracy' : round(accuracy,3),
                
        }, grid_search.cv_results_,best_parameters, grid_search.best_estimator_;

# %%
result = [];
cv_result = [];
best_parameters = [];
estimators = [];
with warnings.catch_warnings():
    warnings.filterwarnings("ignore");
    for problem in problems:
        i = int(re.sub('\D+','',problem['problem']));
        if i not in bestPOS:
            continue;
        r, c, b, e = runML(problem,bestPOS[i]);
        result.append(r);
        cv_result.append(c);
        estimators.append(e);
        b['problem'] = problem['problem'];
        best_parameters.append(b);
# Out:
# Problem: problem00001,  language: en,
# ['PROPN']
# ['PROPN', 'VERB']
# ['PROPN', 'VERB', 'NOUN']
# ['PROPN', 'VERB', 'NOUN', 'ADJ']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM', 'CCONJ']
# ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM', 'CCONJ', 'PART']
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 108 out of 108 | elapsed:  6.7min finished
# Gridsearh 404.305s Best score: 0.469
# Best parameters set:
# 	filter__parts: ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM', 'CCONJ', 'PART']
# 	vect__ngram_range: (2, 4)
#
# Problem: problem00002,  language: en,
# ['ADV']
# ['ADV', 'VERB']
# ['ADV', 'VERB', 'ADJ']
# ['ADV', 'VERB', 'ADJ', 'PRON']
# ['ADV', 'VERB', 'ADJ', 'PRON', 'NOUN']
# ['ADV', 'VERB', 'ADJ', 'PRON', 'NOUN', 'NUM']
# ['ADV', 'VERB', 'ADJ', 'PRON', 'NOUN', 'NUM', 'INTJ']
# ['ADV', 'VERB', 'ADJ', 'PRON', 'NOUN', 'NUM', 'INTJ', 'PROPN']
# ['ADV', 'VERB', 'ADJ', 'PRON', 'NOUN', 'NUM', 'INTJ', 'PROPN', 'ADP']
# ['ADV', 'VERB', 'ADJ', 'PRON', 'NOUN', 'NUM', 'INTJ', 'PROPN', 'ADP', 'CCONJ']
# ['ADV', 'VERB', 'ADJ', 'PRON', 'NOUN', 'NUM', 'INTJ', 'PROPN', 'ADP', 'CCONJ', 'DET']
# ['ADV', 'VERB', 'ADJ', 'PRON', 'NOUN', 'NUM', 'INTJ', 'PROPN', 'ADP', 'CCONJ', 'DET', 'PART']
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 108 out of 108 | elapsed:   31.4s finished
# Gridsearh 31.821s Best score: 0.752
# Best parameters set:
# 	filter__parts: ['ADV', 'VERB', 'ADJ', 'PRON', 'NOUN', 'NUM', 'INTJ', 'PROPN', 'ADP', 'CCONJ', 'DET', 'PART']
# 	vect__ngram_range: (2, 4)
#
# Problem: problem00003,  language: fr,
# ['VERB']
# ['VERB', 'NOUN']
# ['VERB', 'NOUN', 'PROPN']
# ['VERB', 'NOUN', 'PROPN', 'PRON']
# ['VERB', 'NOUN', 'PROPN', 'PRON', 'ADV']
# ['VERB', 'NOUN', 'PROPN', 'PRON', 'ADV', 'SCONJ']
# ['VERB', 'NOUN', 'PROPN', 'PRON', 'ADV', 'SCONJ', 'ADJ']
# ['VERB', 'NOUN', 'PROPN', 'PRON', 'ADV', 'SCONJ', 'ADJ', 'DET']
# ['VERB', 'NOUN', 'PROPN', 'PRON', 'ADV', 'SCONJ', 'ADJ', 'DET', 'CCONJ']
# ['VERB', 'NOUN', 'PROPN', 'PRON', 'ADV', 'SCONJ', 'ADJ', 'DET', 'CCONJ', 'ADP']
# ['VERB', 'NOUN', 'PROPN', 'PRON', 'ADV', 'SCONJ', 'ADJ', 'DET', 'CCONJ', 'ADP', 'AUX']
# Fitting 3 folds for each of 33 candidates, totalling 99 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  99 out of  99 | elapsed:  5.6min finished
# Gridsearh 335.749s Best score: 0.502
# Best parameters set:
# 	filter__parts: ['VERB', 'NOUN', 'PROPN', 'PRON', 'ADV', 'SCONJ', 'ADJ', 'DET', 'CCONJ', 'ADP']
# 	vect__ngram_range: (2, 4)
#
# Problem: problem00004,  language: fr,
# ['NOUN']
# ['NOUN', 'VERB']
# ['NOUN', 'VERB', 'ADV']
# ['NOUN', 'VERB', 'ADV', 'SCONJ']
# ['NOUN', 'VERB', 'ADV', 'SCONJ', 'PROPN']
# ['NOUN', 'VERB', 'ADV', 'SCONJ', 'PROPN', 'PRON']
# ['NOUN', 'VERB', 'ADV', 'SCONJ', 'PROPN', 'PRON', 'CCONJ']
# ['NOUN', 'VERB', 'ADV', 'SCONJ', 'PROPN', 'PRON', 'CCONJ', 'ADP']
# ['NOUN', 'VERB', 'ADV', 'SCONJ', 'PROPN', 'PRON', 'CCONJ', 'ADP', 'AUX']
# ['NOUN', 'VERB', 'ADV', 'SCONJ', 'PROPN', 'PRON', 'CCONJ', 'ADP', 'AUX', 'ADJ']
# ['NOUN', 'VERB', 'ADV', 'SCONJ', 'PROPN', 'PRON', 'CCONJ', 'ADP', 'AUX', 'ADJ', 'DET']
# ['NOUN', 'VERB', 'ADV', 'SCONJ', 'PROPN', 'PRON', 'CCONJ', 'ADP', 'AUX', 'ADJ', 'DET', 'NUM']
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 108 out of 108 | elapsed:   25.9s finished
# Gridsearh 26.182s Best score: 0.719
# Best parameters set:
# 	filter__parts: ['NOUN', 'VERB', 'ADV', 'SCONJ', 'PROPN', 'PRON', 'CCONJ']
# 	vect__ngram_range: (2, 5)
#
# Problem: problem00005,  language: it,
# ['NOUN']
# ['NOUN', 'VERB']
# ['NOUN', 'VERB', 'ADV']
# ['NOUN', 'VERB', 'ADV', 'PROPN']
# ['NOUN', 'VERB', 'ADV', 'PROPN', 'PRON']
# ['NOUN', 'VERB', 'ADV', 'PROPN', 'PRON', 'SCONJ']
# ['NOUN', 'VERB', 'ADV', 'PROPN', 'PRON', 'SCONJ', 'DET']
# ['NOUN', 'VERB', 'ADV', 'PROPN', 'PRON', 'SCONJ', 'DET', 'CONJ']
# ['NOUN', 'VERB', 'ADV', 'PROPN', 'PRON', 'SCONJ', 'DET', 'CONJ', 'ADJ']
# ['NOUN', 'VERB', 'ADV', 'PROPN', 'PRON', 'SCONJ', 'DET', 'CONJ', 'ADJ', 'AUX']
# ['NOUN', 'VERB', 'ADV', 'PROPN', 'PRON', 'SCONJ', 'DET', 'CONJ', 'ADJ', 'AUX', 'ADP']
# Fitting 3 folds for each of 33 candidates, totalling 99 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  99 out of  99 | elapsed:  5.5min finished
# Gridsearh 331.554s Best score: 0.423
# Best parameters set:
# 	filter__parts: ['NOUN', 'VERB', 'ADV', 'PROPN', 'PRON', 'SCONJ', 'DET', 'CONJ', 'ADJ', 'AUX', 'ADP']
# 	vect__ngram_range: (2, 4)
#
# Problem: problem00006,  language: it,
# ['VERB']
# ['VERB', 'NOUN']
# ['VERB', 'NOUN', 'DET']
# ['VERB', 'NOUN', 'DET', 'ADV']
# ['VERB', 'NOUN', 'DET', 'ADV', 'SCONJ']
# ['VERB', 'NOUN', 'DET', 'ADV', 'SCONJ', 'PROPN']
# ['VERB', 'NOUN', 'DET', 'ADV', 'SCONJ', 'PROPN', 'ADJ']
# ['VERB', 'NOUN', 'DET', 'ADV', 'SCONJ', 'PROPN', 'ADJ', 'AUX']
# ['VERB', 'NOUN', 'DET', 'ADV', 'SCONJ', 'PROPN', 'ADJ', 'AUX', 'PRON']
# ['VERB', 'NOUN', 'DET', 'ADV', 'SCONJ', 'PROPN', 'ADJ', 'AUX', 'PRON', 'NUM']
# ['VERB', 'NOUN', 'DET', 'ADV', 'SCONJ', 'PROPN', 'ADJ', 'AUX', 'PRON', 'NUM', 'CONJ']
# ['VERB', 'NOUN', 'DET', 'ADV', 'SCONJ', 'PROPN', 'ADJ', 'AUX', 'PRON', 'NUM', 'CONJ', 'ADP']
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 108 out of 108 | elapsed:   29.4s finished
# Gridsearh 29.958s Best score: 0.808
# Best parameters set:
# 	filter__parts: ['VERB', 'NOUN', 'DET', 'ADV', 'SCONJ', 'PROPN', 'ADJ', 'AUX', 'PRON', 'NUM', 'CONJ', 'ADP']
# 	vect__ngram_range: (2, 5)
#
# Problem: problem00009,  language: sp,
# ['NOUN']
# ['NOUN', 'PROPN']
# ['NOUN', 'PROPN', 'VERB']
# ['NOUN', 'PROPN', 'VERB', 'ADV']
# ['NOUN', 'PROPN', 'VERB', 'ADV', 'ADJ']
# ['NOUN', 'PROPN', 'VERB', 'ADV', 'ADJ', 'PRON']
# ['NOUN', 'PROPN', 'VERB', 'ADV', 'ADJ', 'PRON', 'ADP']
# ['NOUN', 'PROPN', 'VERB', 'ADV', 'ADJ', 'PRON', 'ADP', 'SCONJ']
# ['NOUN', 'PROPN', 'VERB', 'ADV', 'ADJ', 'PRON', 'ADP', 'SCONJ', 'DET']
# ['NOUN', 'PROPN', 'VERB', 'ADV', 'ADJ', 'PRON', 'ADP', 'SCONJ', 'DET', 'AUX']
# ['NOUN', 'PROPN', 'VERB', 'ADV', 'ADJ', 'PRON', 'ADP', 'SCONJ', 'DET', 'AUX', 'CONJ']
# Fitting 3 folds for each of 33 candidates, totalling 99 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  99 out of  99 | elapsed:  5.7min finished
# Gridsearh 340.844s Best score: 0.719
# Best parameters set:
# 	filter__parts: ['NOUN', 'PROPN', 'VERB', 'ADV', 'ADJ', 'PRON', 'ADP', 'SCONJ', 'DET', 'AUX']
# 	vect__ngram_range: (2, 4)
#
# Problem: problem00010,  language: sp,
# ['PROPN']
# ['PROPN', 'NOUN']
# ['PROPN', 'NOUN', 'VERB']
# ['PROPN', 'NOUN', 'VERB', 'ADV']
# ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ']
# ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON']
# ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET']
# ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ']
# ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP']
# ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP', 'AUX']
# ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP', 'AUX', 'NUM']
# ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP', 'AUX', 'NUM', 'CONJ']
# Fitting 3 folds for each of 36 candidates, totalling 108 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 108 out of 108 | elapsed:   28.7s finished
# Gridsearh 29.281s Best score: 0.908
# Best parameters set:
# 	filter__parts: ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP', 'AUX', 'NUM', 'CONJ']
# 	vect__ngram_range: (2, 5)

# %%
df=pd.DataFrame(result)[['problem-name',
                     "language",
                     'macro-f1','macro-precision','macro-recall' ,'micro-accuracy']]

# %%
df
# Out:
#    problem-name language  macro-f1  macro-precision  macro-recall  \
# 0  problem00001       en    0.3440           0.3800        0.4740
# 1  problem00002       en    0.7070           0.7510        0.7000
# 2  problem00003       fr    0.3480           0.3620        0.4240
# 3  problem00004       fr    0.4540           0.5910        0.5600
# 4  problem00005       it    0.4120           0.4270        0.6120
# 5  problem00006       it    0.5110           0.5570        0.6180
# 6  problem00009       sp    0.3740           0.3930        0.4730
# 7  problem00010       sp    0.5510           0.5630        0.5640
#
#    micro-accuracy
# 0          0.4480
# 1          0.9050
# 2          0.3880
# 3          0.4290
# 4          0.4500
# 5          0.6960
# 6          0.4270
# 7          0.7030

# %%
print(df[["macro-f1"]].reset_index().to_latex(index=False).replace("     "," "))
# Out:
# \begin{tabular}{rr}
# \toprule
#  index &  macro-f1 \\
# \midrule
#  0 &    0.3440 \\
#  1 &    0.7070 \\
#  2 &    0.3480 \\
#  3 &    0.4540 \\
#  4 &    0.4120 \\
#  5 &    0.5110 \\
#  6 &    0.3740 \\
#  7 &    0.5510 \\
# \bottomrule
# \end{tabular}

# %%
languages={
    'en':'inglesa',
    'sp':'espanhola',
    'it':'italiana',
    'pl':'polonesa',
    'fr':'francesa'
}

# %%
cv_result2 = [];
dfCV = pd.DataFrame();
for i, c in enumerate(cv_result):
    temp = pd.DataFrame(c);
    temp['problem'] = result[i]['problem-name'];
    temp['language'] = languages[result[i]['language']]
    dfCV = dfCV.append(temp);

for p in [
    'mean_test_score','std_test_score','mean_train_score',   
    'split0_test_score','split0_train_score',
    'split1_test_score','split1_train_score',
    'split2_test_score','split2_train_score']:
    dfCV[p]=dfCV[p].astype(np.float32);

    
dfCV =dfCV[[
    'problem',
    'language',
    'rank_test_score',
    'param_filter__parts',
    'param_vect__ngram_range',
    'mean_test_score',   
    'std_test_score',
    'mean_train_score',   

    'split0_test_score','split0_train_score',
    'split1_test_score','split1_train_score',
    'split2_test_score','split2_train_score',

    'mean_score_time',
    'mean_fit_time',
    'std_fit_time',
    'std_score_time',
    'std_train_score',
]];

dfCV.rename(columns={
    'param_filter__parts':'parts',
    'param_vect__ngram_range':'ngram_range',
},inplace=True);

def nrange(x):
    return sum([i for i in range(x+1)])

dfCV['rangeLen'] = dfCV.ngram_range.apply(lambda x: nrange(x[1])-nrange(x[0]-1))

#print('\',\n\''.join(dfCV.columns))

# %%
dfCV.to_csv('PANAA2018_POSWORD.csv', index=False)

# %%
dfCV = pd.read_csv('PANAA2018_POSWORD.csv', na_values='')

# %%
pd.options.display.max_colwidth = -1
(dfCV[dfCV.rank_test_score == 1])[
    ['problem',
     'language',
    'rank_test_score',
    'mean_test_score',
    'std_test_score',
    'ngram_range',
     'rangeLen',
    'parts']
].sort_values(by=[
    'problem',
    'mean_test_score',
    'parts',
    'rangeLen',
    'ngram_range',
], ascending=[True, False,True,True, True]).head(10)
# Out:
#           problem   language  rank_test_score  mean_test_score  \
# 34   problem00001  inglesa    1               0.4695
# 70   problem00002  inglesa    1               0.7519
# 100  problem00003  francesa   1               0.5023
# 123  problem00004  francesa   1               0.7189
# 172  problem00005  italiana   1               0.4234
# 208  problem00006  italiana   1               0.8083
# 207  problem00006  italiana   1               0.8083
# 238  problem00009  espanhola  1               0.7185
# 277  problem00010  espanhola  1               0.9083
# 276  problem00010  espanhola  1               0.9083
#
#      std_test_score ngram_range  rangeLen  \
# 34  0.0523           (2, 4)      9
# 70  0.0588           (2, 4)      9
# 100 0.0041           (2, 4)      9
# 123 0.1124           (2, 5)      14
# 172 0.0534           (2, 4)      9
# 208 0.1203           (2, 4)      9
# 207 0.1203           (2, 5)      14
# 238 0.0633           (2, 4)      9
# 277 0.0859           (2, 4)      9
# 276 0.0859           (2, 5)      14
#
#                                                                                              parts
# 34   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM', 'CCONJ', 'PART']
# 70   ['ADV', 'VERB', 'ADJ', 'PRON', 'NOUN', 'NUM', 'INTJ', 'PROPN', 'ADP', 'CCONJ', 'DET', 'PART']
# 100  ['VERB', 'NOUN', 'PROPN', 'PRON', 'ADV', 'SCONJ', 'ADJ', 'DET', 'CCONJ', 'ADP']
# 123  ['NOUN', 'VERB', 'ADV', 'SCONJ', 'PROPN', 'PRON', 'CCONJ']
# 172  ['NOUN', 'VERB', 'ADV', 'PROPN', 'PRON', 'SCONJ', 'DET', 'CONJ', 'ADJ', 'AUX', 'ADP']
# 208  ['VERB', 'NOUN', 'DET', 'ADV', 'SCONJ', 'PROPN', 'ADJ', 'AUX', 'PRON', 'NUM', 'CONJ', 'ADP']
# 207  ['VERB', 'NOUN', 'DET', 'ADV', 'SCONJ', 'PROPN', 'ADJ', 'AUX', 'PRON', 'NUM', 'CONJ', 'ADP']
# 238  ['NOUN', 'PROPN', 'VERB', 'ADV', 'ADJ', 'PRON', 'ADP', 'SCONJ', 'DET', 'AUX']
# 277  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP', 'AUX', 'NUM', 'CONJ']
# 276  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP', 'AUX', 'NUM', 'CONJ']

# %%
pd.set_option('display.max_colwidth', -1)
t=(dfCV)[
    ['problem',
     'language',
    'rank_test_score',
    'mean_test_score',
    'std_test_score',
    'ngram_range',
     'rangeLen',
    'parts']
].sort_values(by=[
    'problem',
    'rank_test_score',
    'parts',
    'rangeLen',
    'ngram_range',
], ascending=[True, True,True,True, True])
t
# Out:
#           problem   language  rank_test_score  mean_test_score  \
# 34   problem00001  inglesa    1               0.4695
# 33   problem00001  inglesa    2               0.4609
# 31   problem00001  inglesa    3               0.4367
# 28   problem00001  inglesa    4               0.4344
# 27   problem00001  inglesa    5               0.4302
# 25   problem00001  inglesa    6               0.4300
# 30   problem00001  inglesa    7               0.4176
# 15   problem00001  inglesa    8               0.4157
# 24   problem00001  inglesa    9               0.4094
# 16   problem00001  inglesa    10              0.4036
# 13   problem00001  inglesa    11              0.3834
# 21   problem00001  inglesa    12              0.3719
# 22   problem00001  inglesa    13              0.3699
# 19   problem00001  inglesa    14              0.3606
# 18   problem00001  inglesa    15              0.3546
# 12   problem00001  inglesa    16              0.3276
# 9    problem00001  inglesa    17              0.3227
# 10   problem00001  inglesa    18              0.3091
# 7    problem00001  inglesa    19              0.2805
# 35   problem00001  inglesa    20              0.2444
# 4    problem00001  inglesa    21              0.2434
# 1    problem00001  inglesa    22              0.2354
# 32   problem00001  inglesa    23              0.2207
# 3    problem00001  inglesa    24              0.2179
# 6    problem00001  inglesa    25              0.2089
# 29   problem00001  inglesa    26              0.1919
# 0    problem00001  inglesa    27              0.1789
# 26   problem00001  inglesa    28              0.1695
# 23   problem00001  inglesa    29              0.1368
# 2    problem00001  inglesa    30              0.1311
# ..            ...      ...    ..                 ...
# 271  problem00010  espanhola  5               0.8727
# 270  problem00010  espanhola  5               0.8727
# 244  problem00010  espanhola  9               0.8544
# 243  problem00010  espanhola  9               0.8544
# 256  problem00010  espanhola  11              0.8489
# 255  problem00010  espanhola  11              0.8489
# 259  problem00010  espanhola  13              0.8438
# 258  problem00010  espanhola  13              0.8438
# 261  problem00010  espanhola  15              0.8394
# 265  problem00010  espanhola  16              0.8349
# 253  problem00010  espanhola  17              0.8233
# 252  problem00010  espanhola  18              0.8211
# 264  problem00010  espanhola  19              0.8038
# 247  problem00010  espanhola  20              0.7944
# 246  problem00010  espanhola  20              0.7944
# 262  problem00010  espanhola  22              0.7810
# 245  problem00010  espanhola  23              0.7489
# 249  problem00010  espanhola  24              0.7121
# 250  problem00010  espanhola  25              0.7076
# 269  problem00010  espanhola  26              0.6729
# 278  problem00010  espanhola  27              0.6725
# 275  problem00010  espanhola  27              0.6725
# 272  problem00010  espanhola  27              0.6725
# 266  problem00010  espanhola  30              0.6216
# 263  problem00010  espanhola  31              0.5778
# 260  problem00010  espanhola  32              0.5200
# 257  problem00010  espanhola  33              0.3185
# 254  problem00010  espanhola  34              0.2063
# 248  problem00010  espanhola  35              0.1946
# 251  problem00010  espanhola  36              0.0700
#
#      std_test_score ngram_range  rangeLen  \
# 34  0.0523           (2, 4)      9
# 33  0.0643           (2, 5)      14
# 31  0.0675           (2, 4)      9
# 28  0.0650           (2, 4)      9
# 27  0.0705           (2, 5)      14
# 25  0.0553           (2, 4)      9
# 30  0.0642           (2, 5)      14
# 15  0.0682           (2, 5)      14
# 24  0.0610           (2, 5)      14
# 16  0.0609           (2, 4)      9
# 13  0.0955           (2, 4)      9
# 21  0.0507           (2, 5)      14
# 22  0.0516           (2, 4)      9
# 19  0.0499           (2, 4)      9
# 18  0.0428           (2, 5)      14
# 12  0.0853           (2, 5)      14
# 9   0.1022           (2, 5)      14
# 10  0.0819           (2, 4)      9
# 7   0.0772           (2, 4)      9
# 35  0.0266           (3, 5)      12
# 4   0.0457           (2, 4)      9
# 1   0.0302           (2, 4)      9
# 32  0.0524           (3, 5)      12
# 3   0.0344           (2, 5)      14
# 6   0.0461           (2, 5)      14
# 29  0.0375           (3, 5)      12
# 0   0.0462           (2, 5)      14
# 26  0.0230           (3, 5)      12
# 23  0.0474           (3, 5)      12
# 2   0.0426           (3, 5)      12
# ..     ...              ...      ..
# 271 0.0582           (2, 4)      9
# 270 0.0582           (2, 5)      14
# 244 0.0397           (2, 4)      9
# 243 0.0397           (2, 5)      14
# 256 0.0453           (2, 4)      9
# 255 0.0453           (2, 5)      14
# 259 0.0620           (2, 4)      9
# 258 0.0620           (2, 5)      14
# 261 0.0653           (2, 5)      14
# 265 0.0682           (2, 4)      9
# 253 0.0497           (2, 4)      9
# 252 0.0511           (2, 5)      14
# 264 0.0980           (2, 5)      14
# 247 0.0641           (2, 4)      9
# 246 0.0641           (2, 5)      14
# 262 0.0693           (2, 4)      9
# 245 0.0819           (3, 5)      12
# 249 0.0507           (2, 5)      14
# 250 0.0549           (2, 4)      9
# 269 0.0289           (3, 5)      12
# 278 0.0152           (3, 5)      12
# 275 0.0152           (3, 5)      12
# 272 0.0152           (3, 5)      12
# 266 0.1409           (3, 5)      12
# 263 0.0797           (3, 5)      12
# 260 0.0628           (3, 5)      12
# 257 0.0545           (3, 5)      12
# 254 0.1091           (3, 5)      12
# 248 0.1156           (3, 5)      12
# 251 0.0025           (3, 5)      12
#
#                                                                                              parts
# 34   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM', 'CCONJ', 'PART']
# 33   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM', 'CCONJ', 'PART']
# 31   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM', 'CCONJ']
# 28   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM']
# 27   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM']
# 25   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET']
# 30   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM', 'CCONJ']
# 15   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP']
# 24   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET']
# 16   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP']
# 13   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV']
# 21   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ']
# 22   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ']
# 19   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON']
# 18   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON']
# 12   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV']
# 9    ['PROPN', 'VERB', 'NOUN', 'ADJ']
# 10   ['PROPN', 'VERB', 'NOUN', 'ADJ']
# 7    ['PROPN', 'VERB', 'NOUN']
# 35   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM', 'CCONJ', 'PART']
# 4    ['PROPN', 'VERB']
# 1    ['PROPN']
# 32   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM', 'CCONJ']
# 3    ['PROPN', 'VERB']
# 6    ['PROPN', 'VERB', 'NOUN']
# 29   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM']
# 0    ['PROPN']
# 26   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET']
# 23   ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ']
# 2    ['PROPN']
# ..         ...
# 271  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP', 'AUX']
# 270  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP', 'AUX']
# 244  ['PROPN']
# 243  ['PROPN']
# 256  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ']
# 255  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ']
# 259  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON']
# 258  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON']
# 261  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET']
# 265  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ']
# 253  ['PROPN', 'NOUN', 'VERB', 'ADV']
# 252  ['PROPN', 'NOUN', 'VERB', 'ADV']
# 264  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ']
# 247  ['PROPN', 'NOUN']
# 246  ['PROPN', 'NOUN']
# 262  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET']
# 245  ['PROPN']
# 249  ['PROPN', 'NOUN', 'VERB']
# 250  ['PROPN', 'NOUN', 'VERB']
# 269  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP']
# 278  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP', 'AUX', 'NUM', 'CONJ']
# 275  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP', 'AUX', 'NUM']
# 272  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP', 'AUX']
# 266  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ']
# 263  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET']
# 260  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON']
# 257  ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ']
# 254  ['PROPN', 'NOUN', 'VERB', 'ADV']
# 248  ['PROPN', 'NOUN']
# 251  ['PROPN', 'NOUN', 'VERB']
#
# [279 rows x 8 columns]

# %%
pd.options.display.precision = 3
pd.options.display.max_colwidth = -1
t =(dfCV)[
    ['problem',
     'language',
    'rank_test_score',
    'mean_test_score',
    'ngram_range',
     'rangeLen',
    'parts']
].sort_values(by=[
    'problem',
    'rank_test_score',
    'parts',
    'rangeLen',
    'ngram_range',
], ascending=[True, True,True,True, True])\
.groupby(['problem']).first().drop(columns='rank_test_score').reset_index()


print(u"\\begin{table}[h]\n\\centering\n\\caption{Medida F1 para os parâmetros }")

print(re.sub(r'[ ]{2,}',' ',t.to_latex()))
print ("\label{tab:modelocaracter}")
print(r"\end{table}")
# Out:
# \begin{table}[h]
# \centering
# \caption{Medida F1 para os parâmetros }
# \begin{tabular}{lllrlrl}
# \toprule
# {} & problem & language & mean\_test\_score & ngram\_range & rangeLen & parts \\
# \midrule
# 0 & problem00001 & inglesa & 0.4695 & (2, 4) & 9 & ['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'ADP', 'PRON', 'INTJ', 'DET', 'NUM', 'CCONJ', 'PART'] \\
# 1 & problem00002 & inglesa & 0.7519 & (2, 4) & 9 & ['ADV', 'VERB', 'ADJ', 'PRON', 'NOUN', 'NUM', 'INTJ', 'PROPN', 'ADP', 'CCONJ', 'DET', 'PART'] \\
# 2 & problem00003 & francesa & 0.5023 & (2, 4) & 9 & ['VERB', 'NOUN', 'PROPN', 'PRON', 'ADV', 'SCONJ', 'ADJ', 'DET', 'CCONJ', 'ADP'] \\
# 3 & problem00004 & francesa & 0.7189 & (2, 5) & 14 & ['NOUN', 'VERB', 'ADV', 'SCONJ', 'PROPN', 'PRON', 'CCONJ'] \\
# 4 & problem00005 & italiana & 0.4234 & (2, 4) & 9 & ['NOUN', 'VERB', 'ADV', 'PROPN', 'PRON', 'SCONJ', 'DET', 'CONJ', 'ADJ', 'AUX', 'ADP'] \\
# 5 & problem00006 & italiana & 0.8083 & (2, 4) & 9 & ['VERB', 'NOUN', 'DET', 'ADV', 'SCONJ', 'PROPN', 'ADJ', 'AUX', 'PRON', 'NUM', 'CONJ', 'ADP'] \\
# 6 & problem00009 & espanhola & 0.7185 & (2, 4) & 9 & ['NOUN', 'PROPN', 'VERB', 'ADV', 'ADJ', 'PRON', 'ADP', 'SCONJ', 'DET', 'AUX'] \\
# 7 & problem00010 & espanhola & 0.9083 & (2, 4) & 9 & ['PROPN', 'NOUN', 'VERB', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'ADP', 'AUX', 'NUM', 'CONJ'] \\
# \bottomrule
# \end{tabular}
#
# \label{tab:modelocaracter}
# \end{table}

# %%
# TESTS

# %%
def d(estimator, n_features=15):
    from IPython.display import Markdown, display, HTML
    names = np.array(estimator.named_steps['vect'].get_feature_names());
    classes_ = estimator.named_steps['clf'].classes_;
    weights = estimator.named_steps['clf'].coef_;
    
    def tag(tag, content, attrib=''):
        if attrib != '':
            attrib = ' style="' + attrib+'"'; 
        return ''.join(['<',tag,attrib,' >',content,'</',tag,'>']);
    
    def color(baseColor, intensity):
        r,g,b = baseColor[0:2],baseColor[2:4],baseColor[4:6]
        r,g,b = int(r, 16), int(g, 16), int(b, 16)
        
        f= (1-np.abs(intensity))/3;
        r = r + int((255-r)*f)
        g = g + int((255-g)*f)
        b = b + int((255-b)*f)
        rgb = '#%02x%x%x' % (r, g, b);
        #print(baseColor,rgb,r,g,b,intensity,f)
        return rgb
    
    
    spanStyle ='border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;';
    
    lines = '<table>'+tag('thead',tag('th','Classes')+tag('th','positive')+tag('th','negative'))
    lines += '<tbody>'
    for i,c in enumerate(weights):
        c = np.round(c / np.abs(c).max(),2);
        positive = names[np.argsort(-c)][:n_features];
        positiveV = c[np.argsort(-c)][:n_features]
        negative = names[np.argsort(c)][:n_features];
        negativeV = c[np.argsort(c)][:n_features]
        
        lines += tag('tr',
                     tag('td', re.sub('\D0*','',classes_[i]))
                     + tag('td',''.join([tag('span',d.upper()+' '+str(v),spanStyle+'background:'+color('51A3DD',v)) for d,v in zip(positive,positiveV)]))
                     + tag('td',''.join([tag('span',d.upper()+' '+str(v),spanStyle+'background:'+color('DD5555',v)) for d,v in zip(negative,negativeV)]))
                    )
    lines+= '</tbody></table>'
        
    display(HTML(lines))
    #print(lines)
        
d(estimators[1])
# Out:
# <table><thead ><th >Classes</th><th >positive</th><th >negative</th></thead><tbody><tr ><td >1</td><td ><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#59a7de" >12 SO HE SORT 0.85</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#5ca8df" >11 THE NEXT THING 0.81</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#71b4e3" >12 SO 0.44</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#7ebae5" >13 FOR NOW 0.22</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#7ebae5" >11 THE 0.22</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#7fbbe6" >12 SO HE 0.2</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#85bee7" >12 ONE DAY 0.1</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#89c1e8" >11 BUT SHE APPRECIATED 0.02</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#8ac1e8" >12 ONE DAY OUT 0.01</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#87bfe7" >10 OF COURSE -0.06</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#85bee7" >12 HE -0.09</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#85bee7" >12 HE DID KNOW -0.09</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#85bee7" >12 HE DID -0.1</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#84bee7" >13 THEY -0.11</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#84bee7" >13 IT WAS EERILY -0.11</span></td><td ><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#dd5555" >11 BUT -1.0</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#dd5656" >11 NO HE -0.97</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#de5b5b" >11 NO HE HAS -0.88</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#e06868" >10 PART OF -0.66</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#e16969" >11 BUT SHE -0.64</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#e37474" >13 FOR -0.44</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#e37676" >10 PART -0.41</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#e47878" >13 FOR NOW HE -0.38</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#e47878" >10 OF COURSE HE -0.37</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#e47a7a" >10 PART OF HER -0.34</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#e47a7a" >13 IT -0.33</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#e47c7c" >10 WHEN IT WAS -0.31</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;display:inline-block;background:#e57e7e" >12 ONE -0.27</span><span style="border-radius: 5px;margin:2px 4px;padding:2px; color:#FFF;displa ...

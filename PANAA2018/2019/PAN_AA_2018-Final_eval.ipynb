# %% [markdown]
# # Notebook para o PAN - Atribuição Autoral - 2018 - Final 2019

# %%
# %matplotlib inline

# %% [markdown]
# python basic libs

# %%
#python basic libs
import os;
from os.path import join as pathjoin;
import zipfile;

import re;
import random;
import json;
from collections import defaultdict;
from pprint import pprint
from time import time

# %%
#data analysis libs
import numpy as np;
import pandas as pd;
from pandas.plotting import scatter_matrix;
import matplotlib.pyplot as plt;


import seaborn as sns;

# %%
#machine learning libs
#feature extraction
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn import feature_selection;

#preprocessing and transformation
from sklearn import preprocessing;
from sklearn.preprocessing import MaxAbsScaler;
from sklearn.decomposition import PCA;

from sklearn.base import BaseEstimator, ClassifierMixin

#classifiers
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression


#
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline

#model valuation
from sklearn.model_selection import train_test_split;
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score;

# %% [markdown]
# NLP libraries

# %%
import spacy;
import gensim
import logging
from gensim.models import KeyedVectors
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.CRITICAL)

# %%
from IPython.display import Markdown, display, HTML

# %% [markdown]
# libraries configurations

# %%
import warnings
from sklearn.exceptions import UndefinedMetricWarning
warnings.simplefilter(action='ignore', category=UndefinedMetricWarning)
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
np.set_printoptions(precision=4)
pd.options.display.float_format = '{:,.4f}'.format
sns.set(color_codes=True);

# %%
import platform;
import sklearn;
import scipy;

Markdown(
    "|%-15s|%-65s|\n"%("PACK","VERSION") +
    "|%-15s|%-65s|\n"%('-'*15,'-'*65) +
    ('\n'.join(
    "|%-15s|%-45s| " % (pack, version.strip())
    for pack, version in
    zip(['SO','NumPy','SciPy','Scikit-Learn','Seaborn','Spacy','Gensim'],
        [platform.platform(), np.__version__, scipy.__version__,
         sklearn.__version__, sns.__version__, spacy.__version__, gensim.__version__])

)))
# Out:
# |PACK           |VERSION                                                          |
# |---------------|-----------------------------------------------------------------|
# |SO             |Darwin-18.2.0-x86_64-i386-64bit              |
# |NumPy          |1.15.4                                       |
# |SciPy          |1.1.0                                        |
# |Scikit-Learn   |0.20.1                                       |
# |Seaborn        |0.9.0                                        |
# |Spacy          |2.0.16                                       |
# |Gensim         |3.4.0                                        |

# %% [markdown]
# ### paths configuration

# %% [markdown]
# ### on google

# %% [markdown]
# from google.colab import drive
# drive.mount('/gdrive')

# %% [markdown]
# !ls '/gdrive/My Drive/data_repository'

# %% [markdown]
# baseDir = '/gdrive/My Drive/data_repository';
# modelName = 'char1';
#
# inputDir= pathjoin(baseDir,'pan18aa');
# outputDir= pathjoin(baseDir,'out',modelName);
#
# os.makedirs(outputDir, exist_ok=True)

# %% [markdown]
# def transferCode(filename):
#     with open(os.path.join('/gdrive/My Drive','Colab Notebooks',filename)) as fin:
#         with open(filename,'w') as fout:
#             fout.write(fin.read());

# %% [markdown]
# transferCode('pan.py')
# transferCode('sklearnExtensions.py')

# %% [markdown]
# !ls

# %% [markdown]
# ### on local

# %%
baseDir = '/Users/joseeleandrocustodio/dataScienceNotebook/PANAA2018';

corpusTraining    = 'pan18-cross-domain-authorship-attribution-training-dataset-2017-12-02';
corpusEvaluation = 'pan18-cross-domain-authorship-attribution-test-dataset2-2018-04-20';
corpusEach1 = 'AvaliacaoPT';

currentCorpus = corpusEvaluation;

inputDir= pathjoin(baseDir,currentCorpus);
outputDir= pathjoin(baseDir,'out');
if not os.path.exists(outputDir):
    os.mkdir(outputDir);

# %% [markdown]
# ## Data Ingestion

# %%
import pan
import sklearnExtensions
from sklearnExtensions import DenseTransformer, POSTagTransformer, FilterTagTransformer

# %%
problems = pan.readCollectionsOfProblems(inputDir);

# %%
pd.DataFrame(problems)
# Out:
#                                            candidates  \
# 0   [[hairdryer currently turned on high.\n       ...
# 1   [[hey, perhaps he'd like to test that authorit...
# 2   [[MORE BLISSED OUT AT THE VERY FACT THAT THEY ...
# 3   [[to feel Link inside of him anyways. Ever sin...
# 4   [[Du coin de l'œil il pouvait voir le sourire ...
# 5   [[ai pas vu s'agrandir et s'affirmer, jusqu'à ...
# 6   [[qui allait tout revomir ensuite, Varus serra...
# 7   [[même expérience que toi par rapport aux vamp...
# 8   [[aveva usato anche uno squallidissimo doppio ...
# 9   [[\n\n\n\n\n\n\n\n'Sarai mio.'\n\n\n\n\n\n\n\n...
# 10  [[grafia frettolosa, sconnessa ed ispirata: qu...
# 11  [[circondandogli un polso con la mano per ferm...
# 12  [[zmuszony do odsłaniania się w taki sposób – ...
# 13  [[Nigdy nie sądził, że zazna bólu większego, n...
# 14  [[***\nOgrody Siódmego Nieba są słoneczne i ci...
# 15  [[Wyobrażenie seksu jako aktu dokonującego się...
# 16  [[-¿No me deseas un buen viaje?\n\nLa empujó c...
# 17  [[ropa delante de él.\n\nDespués que los dos e...
# 18  [[que es hora de irnos a casa.\n\n—Pero sí no ...
# 19  [[por un momento rojos como la sangre, la rabi...
#
#     candidates_folder_count encoding language       problem  \
# 0                        20    UTF-8       en  problem00001
# 1                        15    UTF-8       en  problem00002
# 2                        10    UTF-8       en  problem00003
# 3                         5    UTF-8       en  problem00004
# 4                        20    UTF-8       fr  problem00005
# 5                        15    UTF-8       fr  problem00006
# 6                        10    UTF-8       fr  problem00007
# 7                         5    UTF-8       fr  problem00008
# 8                        20    UTF-8       it  problem00009
# 9                        15    UTF-8       it  problem00010
# 10                       10    UTF-8       it  problem00011
# 11                        5    UTF-8       it  problem00012
# 12                       20    UTF-8       pl  problem00013
# 13                       15    UTF-8       pl  problem00014
# 14                       10    UTF-8       pl  problem00015
# 15                        5    UTF-8       pl  problem00016
# 16                       20    UTF-8       sp  problem00017
# 17                       15    UTF-8       sp  problem00018
# 18                       10    UTF-8       sp  problem00019
# 19                        5    UTF-8       sp  problem00020
#
#                                               unknown
# 0   [[looked a bit confused not sure how to answer...
# 1   [[, he pulled away. \n\n"I'm sorry, George." \...
# 2   [[I rasp, and I can actually hear the tirednes...
# 3   [[the swish of his third and incomplete spell ...
# 4   [[put se recoucher l'esprit tranquille, s'emmi...
# 5   [[Marcus l’avait encore une fois humilié.Alors...
# 6   [[, maintenant que ses jambes étaient grandes ...
# 7   [['elle aimait en secret.\n\nUn jaune éclatant...
# 8   [[Se Harry e Draco fossero stati a Hogwarts, p...
# 9   [[stesso e non aveva un buon odore, per quanto...
# 10  [[, tesori... buono, tu, mi hai già fatta amma...
# 11  [[Se Harry e Draco fossero stati a Hogwarts, p...
# 12  [[― Daj mi miesiąc ― mówię po prostu, podchodz...
# 13  [[Malfoy. \n\n— Żeby kogoś zdradzić, trzeba na...
# 14  [[Teraz, albo nigdy. Wziął głęboki wdech. - He...
# 15  [[się uprzejmie.\n\n— Świetnie, świetnie! — Uc...
# 16  [[viaje en el tren quisiera poder enmendar los...
# 17  [[un par de copas, miradas o sonrisas robadas ...
# 18  [[Escuchas unos pasos por fuera de tu habitaci...
# 19  [[era llamarnos únicamente por nuestros apelli...

# %% [markdown]
# # Caching embeddings and POS Tagging

# %% [markdown]
# ### Linguistic anotations

# %%
def cachingPOSTAG(problem, corpusName, taggingVersion='TAG',verbose=False):
    import json;
    if verbose:
        print ("Tagging: %s,  language: %s, " %(problem['problem'],problem['language']), end=' ');
    
    pos_cache_dir = pathjoin('POSTAG_cache',corpusName);
    
    if not os.path.exists(pos_cache_dir):
        os.makedirs(pos_cache_dir);
    
    _id = problem['problem']+problem['language'];
    filename = os.path.join(pos_cache_dir,taggingVersion+'_'+_id+'.json')
    if not os.path.exists(filename):
        lang = problem['language'];
        if lang == 'sp':
            lang = 'es';
        elif lang =='pl':
            print(lang, ' not supported');
            return ;

        train_docs, train_labels, _   = zip(*problem['candidates'])
        problem['training_docs_size'] = len(train_docs);
        test_docs, _, test_filename   = zip(*problem['unknown'])

        t0 = time()
        tagger = POSTagTransformer(language=lang);
        train_docs = tagger.fit_transform(train_docs);
        test_docs = tagger.fit_transform(test_docs);
        
        print("Annotation time %0.3fs" % (time() - t0))
        
        with open(filename,'w') as f:
            json.dump({
                'train':train_docs,
                'train_labels':train_labels,
                'test':test_docs,
                'test_filename':test_filename
            },f);
    else:
        with open(filename,'r') as f:
            data = json.load(f);

            train_docs = data['train'];
            train_labels = data['train_labels'];
            test_docs  = data['test'];
            test_filename = data['test_filename'];
    if verbose:
        print('tagged')
    return train_docs, train_labels, test_docs, test_filename;

for problem in problems:
    cachingPOSTAG(problem,currentCorpus,verbose=True)
# Out:
# Tagging: problem00001,  language: en,  tagged
# Tagging: problem00002,  language: en,  tagged
# Tagging: problem00003,  language: en,  tagged
# Tagging: problem00004,  language: en,  tagged
# Tagging: problem00005,  language: fr,  tagged
# Tagging: problem00006,  language: fr,  tagged
# Tagging: problem00007,  language: fr,  tagged
# Tagging: problem00008,  language: fr,  tagged
# Tagging: problem00009,  language: it,  tagged
# Tagging: problem00010,  language: it,  tagged
# Tagging: problem00011,  language: it,  tagged
# Tagging: problem00012,  language: it,  tagged
# Tagging: problem00013,  language: pl,  pl  not supported
# Tagging: problem00014,  language: pl,  pl  not supported
# Tagging: problem00015,  language: pl,  pl  not supported
# Tagging: problem00016,  language: pl,  pl  not supported
# Tagging: problem00017,  language: sp,  tagged
# Tagging: problem00018,  language: sp,  tagged
# Tagging: problem00019,  language: sp,  tagged
# Tagging: problem00020,  language: sp,  tagged

# %% [markdown]
# ### Embeddings

# %%
def loadEmbeddings(lang):
    if lang == 'sp':
        lang = 'es';
    model = KeyedVectors.load_word2vec_format(os.path.join('embedding_cache','w2v_en.txt.gz'), binary=False, unicode_errors='replace')
    return model;

# %%
regex_cleaning = [re.compile(w) for w in[
    r'[\u4E00-\u9FA5]+',  #chinese,
    r'[\u3040-\u309F]+'  #hiragana
]]

# %%
def problemDoc(problem):
    train_docs, train_labels, _   = zip(*problem['candidates'])
    test_docs, _, test_filename   = zip(*problem['unknown']);
    test_labels = pan.readGroundTruh(pathjoin(inputDir, problem['problem'], 'ground-truth.json'),test_filename)
    return train_docs, train_labels, test_docs, test_labels,test_filename;

# %%
def problemsToTokens(problems):
    def clean(d):
        for r in regex_cleaning:
            d = r.sub('',d);
        return d;
    tokens = {};
    pattern = re.compile(r"(?u)\b\w\w+\b");
    for problem in problems:
        lang = problem['language'];
        if lang == 'sp':
            lang = 'es';
        train_docs, _, test_docs, _, _ = problemDoc(problem);
        docs = list(train_docs)+list(test_docs);

        if lang not in tokens:
            tokens[lang] = list();
        tokens[lang] +=list(set([w  for d in docs for w in pattern.findall(clean(d))]));
        tokens[lang] = sorted(list(set(tokens[lang])));
    return tokens;

# %%
def inspect():
    tokens = problemsToTokens(problems)
    for k,v in tokens.items():
        s = random.randint(0,len(v));
        print(k,len(v), v[s:(s+5)])
inspect();
# Out:
# en 13899 ['Prompted', 'Prone', 'Proper', 'Prophet', 'Proportioned']
# fr 17698 ['hérissa', 'hérisse', 'hérisser', 'hériter', 'héritier']
# it 20690 ['fallo', 'falsa', 'falsamente', 'falso', 'falò']
# pl 35761 ['widocznie', 'widoczności', 'widoczny', 'widocznym', 'widocznymi']
# es 20625 ['manipulado', 'manipuladora', 'manipular', 'manipuló', 'manita']

# %% [markdown]
# It was used embeddings processed by Nordic Language Processing Laboratry
# and availabe on http://vectors.nlpl.eu/repository/. This website was visted in  jan 01 2019

# %%
def outputAnswer(test_pred,test_filename,answerFile):
    # Writing output file using the same format as PAN 
    out_data=[]
    for i,v in enumerate(test_pred):
        out_data.append({'unknown-text': test_filename[i],'predicted-author': v})
    
    with open(answerFile, 'w') as f:
        json.dump(out_data, f, indent=4)

# %%
def fitPipeline(pipe,params,problem,corpus,caching=None):
    print ("Problem: %s,  language: %s, " %(problem['problem'],problem['language']), end=' ');
    
    if caching == 'POS':
        if problem['language'] == 'pl':
            print("POS tagger not found")
            return {
                'problem':problem['problem'],
                'language':problem['language'],
                'n_authors': 0,
                'f1'       : 0,
                'precision': 0,
                'recall'   : 0,
                'accuracy' : 0,
            }, [], [], [], {};
        else:
            train_docs, train_labels, test_docs, test_filename = cachingPOSTAG(problem,corpus);
    elif caching == 'w2v':
        global embeddingsCacheLanguage;
        global embeddingsCache;
        #yes it is uggly to use global var ... but it saved a lot of memory
        if embeddingsCacheLanguage != problem['language']:
            embeddingsCache = loadEmbeddings(problem['language']);
            embeddingsCacheLanguage = problem['language'];
        train_docs, train_labels, test_docs, test_labels,test_filename = problemDoc(problem);
    else:
        train_docs, train_labels, test_docs, test_labels,test_filename = problemDoc(problem);
    
    #using language specific params
    if problem['language'] in params:
        pipe.set_params(**params[problem['language']])
        
    t0 = time()
    pipe.fit(train_docs, train_labels)
    print("Fitted in %0.3fs" % (time() - t0), end=' ');
    
    t0 = time()
    test_pred=pipe.predict(test_docs);
    train_prob=pipe.predict_proba(train_docs);
    test_prob=pipe.predict_proba(test_docs);
    print("Predicted in %0.3fs" % (time() - t0));
    
    answerFile = pathjoin(outputDir,'answers-'+problem['problem']+'.json');
    outputAnswer(test_pred,test_filename,answerFile)
    
    #calculating the performance using PAN evaluation code
    grountTruthFile = pathjoin(inputDir, problem['problem'], 'ground-truth.json');
    f1,precision,recall,accuracy=pan.evaluate(grountTruthFile,answerFile);
    
    
    return {
        'problem':problem['problem'],
        'language':problem['language'],
        'n_authors':len(set(train_labels)),
        'f1'       : round(f1,3),
        'precision': round(precision,3),
        'recall'   : round(recall,3),
        'accuracy' : round(accuracy,3),
    }, test_pred, train_prob, test_prob, pipe.get_params();

# %% [markdown]
# # Model 1: Character

# %%
pipelineChar = Pipeline([
    ('vect',   TfidfVectorizer(analyzer='char',
                               min_df=0.01,
                               max_df=1.0,
                               norm='l2',
                               ngram_range=(2, 5),
                               sublinear_tf=True,
                               lowercase =False)),
    ('scaler', preprocessing.MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', linear_model.LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineCharParams= {
    'it':{
        'vect__ngram_range': (3, 5),
    },
    'pl':{
        'vect__ngram_range': (2, 3),
    }
}

# %% [markdown]
# # Model 2: Word

# %%
pipelineWord = Pipeline([
    ('vect',   TfidfVectorizer(analyzer='word',
                               norm='l1',
                               min_df=2,
                               max_df=1.0,
                               ngram_range=(1, 2),
                               smooth_idf=True,
                               lowercase =True,
                               sublinear_tf=True)),
    ('dense',  DenseTransformer()),
    ('scaler', preprocessing.MaxAbsScaler()),
    ('transf', PCA(0.999)),
    ('clf', linear_model.LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineWordParams= {
    'en':{
        'vect__ngram_range': (1, 3),
        'vect__norm': 'l2',
    },

    'pl':{
        'vect__norm': 'l2',
     },
}

# %% [markdown]
# # Model 3: distortions

# %%
distortions = [
    (r"[A-Z]"          ,'U','Upcase '),
    (r"[a-z]"          ,'l','lowercase'),
    (r"[À-ÿĄ-ż]"       ,'d','Diacrit'),
    (r"\d"             ,'D','Digits'),
    (r"[\n\r\t]"       ,'E','Paragraph control'),
    (r"\–|\-|\_|\—"    ,'H','Hyphen'),
    (r"\"|\'|’|[“”]"   ,'Q','quotation'),
    (r"\s"             ,'S','Spaces'),
    (r"\(|\)|\[|\]\{|\}|\«|\»",'G','Groups'),
    (r"…",'','...'),
    (r"\.|\,|[?]|\!|\:|\;|\„|\*|\/"   ,'P','Punctuation'),
    (r"[^aUldDEHQSGP]", 'X','Unkown'),
]

distortions = [(re.compile(d[0]), d[1],d[2]) for d in distortions]

# %%
class DistortionTransformer(BaseEstimator):
    def __init__(self,verbose=False):
        self.verbose = verbose;
        
    def _distortion(self,doc):
        for d in distortions:
            doc = d[0].sub(d[1],doc);
        return doc;

    def transform(self, X, y=None):
        t0 = time()
        if self.verbose:
            print('filtered in', end=' ')

        X = [self._distortion(doc) for doc in X]
        
        if self.verbose:
            print(" %0.3fs" % (time() - t0))
        return np.array(X);       

    def fit(self, X, y=None):
        self.is_fitted = True
        return self

    def fit_transform(self, X, y=None):
        return self.transform(X=X, y=y)

# %%
pipelineDistortion = Pipeline([
    ('filter',DistortionTransformer()),
    ('vect', TfidfVectorizer(
            analyzer='char',
            min_df=0.01,
            lowercase=False,
            norm='l2',
            sublinear_tf=True,
            ngram_range=(1, 5),
            )
    ),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineDistortionsParams = {
    'en':{
        'clf__C': 0.1,
        'vect__norm': 'l1',        
    },
    'fr':{
        'vect__norm': 'l1',
        'vect__ngram_range': (2, 5),
    },
    'it':{
        'clf__C': 0.1,
    },
    'sp':{
        'vect__norm': 'l1',
    }
}

# %% [markdown]
# # Model 4: POS

# %%
#train_docs, train_labels, test_docs, test_filename = cachingPOSTAG(problem)

pipelinePOS = Pipeline([
    ('filter',FilterTagTransformer(token='POS')),
    ('vect', TfidfVectorizer(
                        min_df=0.01,
                        lowercase=False,
                        use_idf=True,
                        norm='l1',
                        sublinear_tf=False,
                        ngram_range=(1, 5)
            )),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
])

# %% [markdown]
# O parametro sublinear_tf=True apresentou performance ruim em todos os casos de teste exceto o melhor.
# Como o melhor caso não é garantido nos conjuntos de avaliação, foi decidido que ele seria mantido como False.
#
# O parametro L1 apresentou performance melhor nos conjuntos com 5 candidatos. No entendo, o conjunto de validação conterá de 5 a 20 e portanto foi escolhido manter o valor l2

# %% [markdown]
# # Model 5: TAG  (granular POS)

# %%
def spaceTokenizer(x):
    return x.split(" ");

# %%
pipelineTag = Pipeline([
    ('filter',FilterTagTransformer(token='TAG')),
    ('vect', TfidfVectorizer(
                               tokenizer=spaceTokenizer,
                               min_df=0.01,
                               lowercase=False,
                               sublinear_tf=True,
                               use_idf=True,
                               norm='l2',
                                ngram_range=(1,3),
                              )),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=0.1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineTagParams = {
    'fr':{
        'vect__ngram_range' :(1,5),
    },
    'sp':{
        'vect__ngram_range' :(1,5),
        'clf__C':1,
    }
}

# %% [markdown]
# # Model 6: Sintatic Dependency

# %%
pipelineDEP = Pipeline([
    ('filter',FilterTagTransformer(token='DEP')),
    ('vect', TfidfVectorizer(
                    analyzer='word',
                    min_df=0.01,
                    lowercase=False,
                    use_idf=True,
                    norm='l2',
                    ngram_range=(1,5),
            )),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineDEPParams = {
    'en':{
        'clf__C':0.1,
    },
    'fr':{
        'clf__C':0.1,
    },
    'it':{
        'vect__ngram_range' :(1,3),
    },
}

# %% [markdown]
# # Model 7 : Char with POS filter

# %% [markdown]
# en1['PUNCT', 'PROPN', 'VERB', 'NOUN', 'ADV', 'ADJ', 'ADP', 'INTJ', 'PRON', 'DET', 'CCONJ', 'NUM', 'PART']
# en2['PUNCT', 'VERB', 'ADV', 'PROPN', 'NOUN', 'NUM', 'ADJ', 'PRON', 'INTJ', 'ADP', 'PART', 'DET', 'CCONJ']
#
# fr1['NOUN', 'VERB', 'PROPN', 'ADV', 'ADJ', 'PRON', 'PUNCT', 'ADP', 'DET', 'AUX', 'CCONJ', 'X', 'SCONJ', 'NUM']
# fr2['NOUN', 'ADV', 'VERB', 'PROPN', 'ADJ', 'X', 'SCONJ', 'DET', 'PRON', 'AUX', 'CCONJ', 'PUNCT', 'NUM', 'ADP']
#
# it1['VERB', 'NOUN', 'PUNCT', 'PROPN', 'ADV', 'ADJ', 'PRON', 'DET', 'SCONJ', 'AUX', 'CONJ', 'X', 'ADP', 'INTJ', 'NUM']
# it2['VERB', 'PROPN', 'PUNCT', 'ADV', 'NOUN', 'PRON', 'SCONJ', 'AUX', 'ADJ', 'NUM', 'CONJ', 'DET', 'INTJ', 'ADP', 'X']
#
# sp1['PROPN', 'VERB', 'NOUN', 'PUNCT', 'ADJ', 'ADV', 'PRON', 'AUX', 'SCONJ', 'ADP', 'CONJ', 'DET', 'INTJ', 'NUM']
# sp2['PROPN', 'VERB', 'NOUN', 'ADJ', 'ADV', 'SCONJ', 'ADP', 'PUNCT', 'PRON', 'DET', 'CONJ', 'AUX', 'NUM', 'INTJ']

# %%
#train_docs, train_labels, test_docs, test_filename = cachingPOSTAG(problem)

pipelineCharFilter = Pipeline([
    ('filter',FilterTagTransformer(token='filter')),
    ('vect', TfidfVectorizer(
            analyzer='char_wb',
            min_df=0.01,
            lowercase=False,
            ngram_range=(2,5),
            norm='l2',sublinear_tf=True
        )
    ),
    ('scaler', MaxAbsScaler()),
    ('dense',  DenseTransformer()),
    ('transf', PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineCharFilterParams = {
    'en':{
        'filter__parts': ['PUNCT', 'PROPN', 'VERB', 'NOUN', 'ADV', 'ADJ', 'ADP', 'INTJ', 'PRON', 'DET', 'CCONJ', 'NUM', 'PART']
    },
    'fr':{
        'filter__parts': ['NOUN', 'ADV', 'VERB', 'PROPN', 'ADJ', 'X', 'SCONJ', 'DET', 'PRON', 'AUX', 'CCONJ', 'PUNCT']
    },
    'it':{
        'filter__parts': ['VERB', 'NOUN', 'PUNCT', 'PROPN', 'ADV', 'ADJ', 'PRON']
    },
    'sp':{
        'filter__parts': ['PROPN', 'VERB', 'NOUN', 'PUNCT', 'ADJ', 'ADV', 'PRON', 'AUX', 'SCONJ', 'ADP', 'CONJ', 'DET']
    }
}

# %% [markdown]
# # Model 8: Word Embeddings

# %%
embeddingsCacheLanguage = None;
embeddingsCache = None;

# %%
from scipy import sparse
from sklearn.utils import assert_all_finite

class EmbeddingVectorizer(BaseEstimator):
    def __init__(self,norm=None,analyzer='word',min_df=1,lowercase=False,sublinear_tf=True,use_idf=True,binary=False):
        self.norm        = norm;
        self.analyzer    = analyzer;
        self.min_df      = min_df;
        self.lowercase   = lowercase;
        self.sublinear_tf= sublinear_tf;
        self.use_idf     = use_idf;
        self.binary      = binary;
        
    def fit(self, X, y=None):
        self.dim_ = len(embeddingsCache.vectors[0]);
        #self.dim_ = len(embeddingsCache[list(embeddingsCache.keys())[0]])
        self.vect = TfidfVectorizer(**self.get_params())
        self.vect.fit(X,y);
        self.word_vectors_ = np.zeros((len(self.vect.vocabulary_), self.dim_));
        
        #this arrays says if a word in the vocab has 
        self.missingWord_  = np.zeros(len(self.vect.vocabulary_),dtype=np.int8);
        
        blank = np.zeros(self.dim_);

        for  word, index in self.vect.vocabulary_.items():
            temp = blank.copy();
            for w in [word, word.lower(), word.capitalize()]:
                if w in embeddingsCache:
                    temp = embeddingsCache[w];
                    break;
            if temp.sum() == 0 :
                self.missingWord_[index] = 1;
            self.word_vectors_[index,:] = temp;
        return self
    
    def transform(self, X):
        import gc;
        gc.collect()
        X = self.vect.transform(X);
        
        X = sparse.csc_matrix(X);
        V = sparse.csc_matrix(self.word_vectors_);
        M = sparse.csc_matrix(self.missingWord_).T;
        
        missing = preprocessing.normalize((X>0).dot(M),norm='l1');
        missing = sparse.csc_matrix(missing.reshape(-1,1));
        
        #memory friendly dot product
        X  = preprocessing.normalize(X.dot(V),norm='l1');
        
        #last columns will contain the embedding coverage
        X = sparse.hstack([X,missing]);
        
        return X;
    
    def fit_transform(self, X, y=None):
        self.fit(X,y);
        return self.transform(X)
    
    def get_feature_names():
        return self.vect.get_feature_names();

# %%
pipelineEmbeddings = Pipeline([
    ('vect', EmbeddingVectorizer(
            analyzer='word',
            min_df=0.01,
            lowercase=False,
            sublinear_tf=False,
            norm='l1',
            use_idf=False
            )
    ),
    ('scaler',preprocessing.MaxAbsScaler()),
    ('dense',DenseTransformer()),
    ('pca',PCA(0.999)),
    ('clf', LogisticRegression(random_state=0,C=1,multi_class='multinomial', solver='newton-cg')),
])

# %%
pipelineEmbeddingsParams = {
    'fr':{
        'vect__sublinear_tf': True,
        'vect__use_idf': True,
    },

    'it':{
        'vect__use_idf': True,
    },

    'pl':{
        'clf__C': 0.1,
        'vect__use_idf': False,
        'vect__sublinear_tf': True,
    },
    'sp':{
        'vect__sublinear_tf': True,
        'vect__use_idf': True,
    },
}

# %% [markdown]
# # Applying models

# %%
models =[
    ('char',pipelineChar,pipelineCharParams,None),
    ('word',pipelineWord,pipelineWordParams,None),
    ('dist',pipelineDistortion,pipelineDistortionsParams,None),
    ('pos',pipelinePOS,{},'POS'),
    ('tag',pipelineTag,pipelineTagParams,'POS'),
    ('dep',pipelineDEP,pipelineDEPParams,'POS'),
    ('charFilter',pipelineCharFilter,pipelineCharFilterParams,'POS'),
    ('w2v',pipelineEmbeddings,pipelineEmbeddingsParams,'w2v'),
]

results = {};

for model in models:
    if model[0] in results:
        continue;
    print(('_'*100)+'\n'+model[0]+'\n'+('_'*100))
    result= {
        'metric':[],
        'pred':[],
        'prob_train':[],
        'prob_test':[],
        'params':[],
    }
    for problem in problems:
        metric, pred, prob_train, prob_test, params = fitPipeline(model[1], model[2],problem, caching=model[3],corpus=currentCorpus);
        result['metric'].append(metric);
        result['pred'].append(pred);
        result['prob_train'].append(prob_train);
        result['prob_test'].append(prob_test);
        result['params'].append(params);
    results[model[0]]=result;
# Out:
# ____________________________________________________________________________________________________
# char
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 5.510s Predicted in 6.010s
# Problem: problem00002,  language: en,  Fitted in 3.543s Predicted in 3.510s
# Problem: problem00003,  language: en,  Fitted in 2.568s Predicted in 2.268s
# Problem: problem00004,  language: en,  Fitted in 1.028s Predicted in 1.297s
# Problem: problem00005,  language: fr,  Fitted in 3.731s Predicted in 6.085s
# Problem: problem00006,  language: fr,  Fitted in 3.354s Predicted in 4.628s
# Problem: problem00007,  language: fr,  Fitted in 2.550s Predicted in 2.710s
# Problem: problem00008,  language: fr,  Fitted in 0.953s Predicted in 1.162s
# Problem: problem00009,  language: it,  Fitted in 3.273s Predicted in 4.525s
# Problem: problem00010,  language: it,  Fitted in 3.346s Predicted in 3.452s
# Problem: problem00011,  language: it,  Fitted in 2.187s Predicted in 1.780s
# Problem: problem00012,  language: it,  Fitted in 0.786s Predicted in 1.467s
# Problem: problem00013,  language: pl,  Fitted in 1.097s Predicted in 2.682s
# Problem: problem00014,  language: pl,  Fitted in 0.792s Predicted in 2.143s
# Problem: problem00015,  language: pl,  Fitted in 0.528s Predicted in 1.111s
# Problem: problem00016,  language: pl,  Fitted in 0.296s Predicted in 0.753s
# Problem: problem00017,  language: sp,  Fitted in 0.891s Predicted in 2.527s
# Problem: problem00018,  language: sp,  Fitted in 0.767s Predicted in 1.977s
# Problem: problem00019,  language: sp,  Fitted in 0.438s Predicted in 1.301s
# Problem: problem00020,  language: sp,  Fitted in 0.242s Predicted in 0.583s
# ____________________________________________________________________________________________________
# word
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 1.264s Predicted in 0.879s
# Problem: problem00002,  language: en,  Fitted in 0.802s Predicted in 0.592s
# Problem: problem00003,  language: en,  Fitted in 0.495s Predicted in 0.372s
# Problem: problem00004,  language: en,  Fitted in 0.255s Predicted in 0.165s
# Problem: problem00005,  language: fr,  Fitted in 1.098s Predicted in 0.802s
# Problem: problem00006,  language: fr,  Fitted in 0.907s Predicted in 0.638s
# Problem: problem00007,  language: fr,  Fitted in 0.499s Predicted in 0.404s
# Problem: problem00008,  language: fr,  Fitted in 0.237s Predicted in 0.174s
# Problem: problem00009,  language: it,  Fitted in 1.143s Predicted in 0.907s
# Problem: problem00010,  language: it,  Fitted in 0.841s Predicted in 0.638s
# Problem: problem00011,  language: it,  Fitted in 0.533s Predicted in 0.345s
# Problem: problem00012,  language: it,  Fitted in 0.309s Predicted in 0.247s
# Problem: problem00013,  language: pl,  Fitted in 1.328s Predicted in 1.091s
# Problem: problem00014,  language: pl,  Fitted in 0.844s Predicted in 0.804s
# Problem: problem00015,  language: pl,  Fitted in 0.498s Predicted in 0.350s
# Problem: problem00016,  language: pl,  Fitted in 0.268s Predicted in 0.334s
# Problem: problem00017,  language: sp,  Fitted in 1.531s Predicted in 1.356s
# Problem: problem00018,  language: sp,  Fitted in 1.028s Predicted in 0.842s
# Problem: problem00019,  language: sp,  Fitted in 0.596s Predicted in 0.537s
# Problem: problem00020,  language: sp,  Fitted in 0.282s Predicted in 0.224s
# ____________________________________________________________________________________________________
# dist
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 1.564s Predicted in 4.230s
# Problem: problem00002,  language: en,  Fitted in 1.294s Predicted in 3.396s
# Problem: problem00003,  language: en,  Fitted in 0.777s Predicted in 2.158s
# Problem: problem00004,  language: en,  Fitted in 0.478s Predicted in 1.215s
# Problem: problem00005,  language: fr,  Fitted in 1.625s Predicted in 4.224s
# Problem: problem00006,  language: fr,  Fitted in 1.105s Predicted in 3.605s
# Problem: problem00007,  language: fr,  Fitted in 0.721s Predicted in 2.130s
# Problem: problem00008,  language: fr,  Fitted in 0.387s Predicted in 1.057s
# Problem: problem00009,  language: it,  Fitted in 1.701s Predicted in 4.026s
# Problem: problem00010,  language: it,  Fitted in 1.204s Predicted in 2.833s
# Problem: problem00011,  language: it,  Fitted in 1.522s Predicted in 2.037s
# Problem: problem00012,  language: it,  Fitted in 0.461s Predicted in 1.681s
# Problem: problem00013,  language: pl,  Fitted in 1.635s Predicted in 5.250s
# Problem: problem00014,  language: pl,  Fitted in 1.322s Predicted in 4.298s
# Problem: problem00015,  language: pl,  Fitted in 1.001s Predicted in 2.041s
# Problem: problem00016,  language: pl,  Fitted in 0.468s Predicted in 2.424s
# Problem: problem00017,  language: sp,  Fitted in 1.821s Predicted in 4.839s
# Problem: problem00018,  language: sp,  Fitted in 1.111s Predicted in 3.805s
# Problem: problem00019,  language: sp,  Fitted in 0.893s Predicted in 2.720s
# Problem: problem00020,  language: sp,  Fitted in 0.655s Predicted in 1.745s
# ____________________________________________________________________________________________________
# pos
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 1.236s Predicted in 1.529s
# Problem: problem00002,  language: en,  Fitted in 1.001s Predicted in 1.313s
# Problem: problem00003,  language: en,  Fitted in 0.603s Predicted in 0.948s
# Problem: problem00004,  language: en,  Fitted in 0.395s Predicted in 0.412s
# Problem: problem00005,  language: fr,  Fitted in 1.107s Predicted in 1.625s
# Problem: problem00006,  language: fr,  Fitted in 0.995s Predicted in 1.298s
# Problem: problem00007,  language: fr,  Fitted in 0.607s Predicted in 0.779s
# Problem: problem00008,  language: fr,  Fitted in 0.322s Predicted in 0.347s
# Problem: problem00009,  language: it,  Fitted in 0.962s Predicted in 1.471s
# Problem: problem00010,  language: it,  Fitted in 0.798s Predicted in 1.099s
# Problem: problem00011,  language: it,  Fitted in 0.684s Predicted in 0.768s
# Problem: problem00012,  language: it,  Fitted in 0.355s Predicted in 0.552s
# Problem: problem00013,  language: pl,  POS tagger not found
# Problem: problem00014,  language: pl,  POS tagger not found
# Problem: problem00015,  language: pl,  POS tagger not found
# Problem: problem00016,  language: pl,  POS tagger not found
# Problem: problem00017,  language: sp,  Fitted in 1.232s Predicted in 1.810s
# Problem: problem00018,  language: sp,  Fitted in 0.879s Predicted in 1.398s
# Problem: problem00019,  language: sp,  Fitted in 0.660s Predicted in 1.017s
# Problem: problem00020,  language: sp,  Fitted in 0.343s Predicted in 0.479s
# ____________________________________________________________________________________________________
# tag
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 0.418s Predicted in 0.760s
# Problem: problem00002,  language: en,  Fitted in 0.285s Predicted in 0.617s
# Problem: problem00003,  language: en,  Fitted in 0.227s Predicted in 0.406s
# Problem: problem00004,  language: en,  Fitted in 0.135s Predicted in 0.179s
# Problem: problem00005,  language: fr,  Fitted in 1.195s Predicted in 1.778s
# Problem: problem00006,  language: fr,  Fitted in 0.835s Predicted in 1.238s
# Problem: problem00007,  language: fr,  Fitted in 0.658s Predicted in 0.859s
# Problem: problem00008,  language: fr,  Fitted in 0.278s Predicted in 0.385s
# Problem: problem00009,  language: it,  Fitted in 1.345s Predicted in 1.576s
# Problem: problem00010,  language: it,  Fitted in 1.118s Predicted in 1.293s
# Problem: problem00011,  language: it,  Fitted in 1.046s Predicted in 0.815s
# Problem: problem00012,  language: it,  Fitted in 0.346s Predicted in 0.586s
# Problem: problem00013,  language: pl,  POS tagger not found
# Problem: problem00014,  language: pl,  POS tagger not found
# Problem: problem00015,  language: pl,  POS tagger not found
# Problem: problem00016,  language: pl,  POS tagger not found
# Problem: problem00017,  language: sp,  Fitted in 1.095s Predicted in 2.210s
# Problem: problem00018,  language: sp,  Fitted in 0.823s Predicted in 1.196s
# Problem: problem00019,  language: sp,  Fitted in 0.553s Predicted in 0.790s
# Problem: problem00020,  language: sp,  Fitted in 0.215s Predicted in 0.317s
# ____________________________________________________________________________________________________
# dep
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 1.065s Predicted in 1.151s
# Problem: problem00002,  language: en,  Fitted in 0.857s Predicted in 0.928s
# Problem: problem00003,  language: en,  Fitted in 0.738s Predicted in 0.628s
# Problem: problem00004,  language: en,  Fitted in 0.253s Predicted in 0.272s
# Problem: problem00005,  language: fr,  Fitted in 1.098s Predicted in 1.264s
# Problem: problem00006,  language: fr,  Fitted in 0.812s Predicted in 0.958s
# Problem: problem00007,  language: fr,  Fitted in 0.713s Predicted in 0.664s
# Problem: problem00008,  language: fr,  Fitted in 0.274s Predicted in 0.293s
# Problem: problem00009,  language: it,  Fitted in 0.324s Predicted in 0.632s
# Problem: problem00010,  language: it,  Fitted in 0.321s Predicted in 0.462s
# Problem: problem00011,  language: it,  Fitted in 0.154s Predicted in 0.242s
# Problem: problem00012,  language: it,  Fitted in 0.135s Predicted in 0.205s
# Problem: problem00013,  language: pl,  POS tagger not found
# Problem: problem00014,  language: pl,  POS tagger not found
# Problem: problem00015,  language: pl,  POS tagger not found
# Problem: problem00016,  language: pl,  POS tagger not found
# Problem: problem00017,  language: sp,  Fitted in 0.305s Predicted in 0.733s
# Problem: problem00018,  language: sp,  Fitted in 0.226s Predicted in 0.536s
# Problem: problem00019,  language: sp,  Fitted in 0.169s Predicted in 0.391s
# Problem: problem00020,  language: sp,  Fitted in 0.082s Predicted in 0.150s
# ____________________________________________________________________________________________________
# charFilter
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 1.329s Predicted in 2.398s
# Problem: problem00002,  language: en,  Fitted in 1.070s Predicted in 1.927s
# Problem: problem00003,  language: en,  Fitted in 0.859s Predicted in 1.228s
# Problem: problem00004,  language: en,  Fitted in 0.353s Predicted in 0.535s
# Problem: problem00005,  language: fr,  Fitted in 1.405s Predicted in 2.525s
# Problem: problem00006,  language: fr,  Fitted in 1.181s Predicted in 1.923s
# Problem: problem00007,  language: fr,  Fitted in 0.771s Predicted in 1.304s
# Problem: problem00008,  language: fr,  Fitted in 0.349s Predicted in 0.550s
# Problem: problem00009,  language: it,  Fitted in 1.385s Predicted in 2.498s
# Problem: problem00010,  language: it,  Fitted in 1.038s Predicted in 1.852s
# Problem: problem00011,  language: it,  Fitted in 0.843s Predicted in 1.020s
# Problem: problem00012,  language: it,  Fitted in 0.432s Predicted in 0.877s
# Problem: problem00013,  language: pl,  POS tagger not found
# Problem: problem00014,  language: pl,  POS tagger not found
# Problem: problem00015,  language: pl,  POS tagger not found
# Problem: problem00016,  language: pl,  POS tagger not found
# Problem: problem00017,  language: sp,  Fitted in 1.561s Predicted in 3.417s
# Problem: problem00018,  language: sp,  Fitted in 1.211s Predicted in 2.675s
# Problem: problem00019,  language: sp,  Fitted in 0.886s Predicted in 1.796s
# Problem: problem00020,  language: sp,  Fitted in 0.400s Predicted in 0.754s
# ____________________________________________________________________________________________________
# w2v
# ____________________________________________________________________________________________________
# Problem: problem00001,  language: en,  Fitted in 0.403s Predicted in 0.572s
# Problem: problem00002,  language: en,  Fitted in 0.330s Predicted in 0.522s
# Problem: problem00003,  language: en,  Fitted in 0.404s Predicted in 0.609s
# Problem: problem00004,  language: en,  Fitted in 0.241s Predicted in 0.386s
# Problem: problem00005,  language: fr,  Fitted in 0.305s Predicted in 0.411s
# Problem: problem00006,  language: fr,  Fitted in 0.250s Predicted in 0.363s
# Problem: problem00007,  language: fr,  Fitted in 0.274s Predicted in 0.327s
# Problem: problem00008,  language: fr,  Fitted in 0.176s Predicted in 0.268s
# Problem: problem00009,  language: it,  Fitted in 0.313s Predicted in 0.413s
# Problem: problem00010,  language: it,  Fitted in 0.259s Predicted in 0.348s
# Problem: problem00011,  language: it,  Fitted in 0.287s Predicted in 0.326s
# Problem: problem00012,  language: it,  Fitted in 0.186s Predicted in 0.292s
# Problem: problem00013,  language: pl,  Fitted in 0.341s Predicted in 0.449s
# Problem: problem00014,  language: pl,  Fitted in 0.291s Predicted in 0.380s
# Problem: problem00015,  language: pl,  Fitted in 0.333s Predicted in 0.352s
# Problem: problem00016,  language: pl,  Fitted in 0.199s Predicted in 0.294s
# Problem: problem00017,  language: sp,  Fitted in 0.320s Predicted in 0.462s
# Problem: problem00018,  language: sp,  Fitted in 0.258s Predicted in 0.421s
# Problem: problem00019,  language: sp,  Fitted in 0.273s Predicted in 0.382s
# Problem: problem00020,  language: sp,  Fitted in 0.209s Predicted in 0.309s

# %%
dfMetric = pd.DataFrame();
for m in results:
    df = pd.DataFrame(results[m]['metric'])[['problem','n_authors','language','f1','precision','recall','accuracy']]
    df['model']=m
    dfMetric= dfMetric.append(df)
    
dfMetric.fillna(value=0) \
    .pivot(index='problem',columns='model',values=['f1','accuracy'])\
    .style.background_gradient(subset=['f1'], axis=1, cmap=plt.cm.Blues)\
    .background_gradient(subset=['accuracy'], axis=1, cmap=plt.cm.Greens)
# Out:
# <style  type="text/css" >
#     #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col1 {
#             background-color:  #8dc1dd;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col2 {
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col3 {
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col4 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col5 {
#             background-color:  #a8cee4;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col7 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col8 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col9 {
#             background-color:  #3fa95c;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col10 {
#             background-color:  #b4e1ad;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col11 {
#             background-color:  #bce4b5;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col12 {
#             background-color:  #8ed08b;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col13 {
#             background-color:  #62bb6d;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col14 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row0_col15 {
#             background-color:  #39a257;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col1 {
#             background-color:  #8cc0dd;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col2 {
#             background-color:  #e3eef9;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col3 {
#             background-color:  #cbdef1;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col4 {
#             background-color:  #9dcae1;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col5 {
#             background-color:  #75b4d8;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col7 {
#             background-color:  #3181bd;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col8 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col9 {
#             background-color:  #4bb062;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col10 {
#             background-color:  #dbf1d6;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col11 {
#             background-color:  #b8e3b2;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col12 {
#             background-color:  #80ca80;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col13 {
#             background-color:  #73c476;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col14 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row1_col15 {
#             background-color:  #3fa85b;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col1 {
#             background-color:  #3383be;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col2 {
#             background-color:  #a3cce3;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col3 {
#             background-color:  #97c6df;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col4 {
#             background-color:  #95c5df;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col5 {
#             background-color:  #5da5d1;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col7 {
#             background-color:  #4594c7;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col8 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col9 {
#             background-color:  #127c39;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col10 {
#             background-color:  #c8e9c1;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col11 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col12 {
#             background-color:  #a0d99b;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col13 {
#             background-color:  #40aa5d;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col14 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row2_col15 {
#             background-color:  #319a50;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row3_col0 {
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row3_col1 {
#             background-color:  #08458a;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row3_col2 {
#             background-color:  #1663aa;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row3_col3 {
#             background-color:  #caddf0;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row3_col4 {
#             background-color:  #08458a;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row3_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row3_col6 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row3_col7 {
#             background-color:  #79b5d9;
#             color:  #000000;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row3_col8 {
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row3_col9 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row3_col10 {
#             background-color:  #157f3b;
#             color:  #f1f1f1;
#         }    #T_058ea51e_2f32_11e9_926d_8c8590360b07row3_col11 {
#             background-color:  #f7fcf5;

# %%
dfMetric = dfMetric[dfMetric.n_authors.values != 0]
dfMetric['id'] = dfMetric.problem.apply(lambda x: int(re.sub('\D','',x)))
g = sns.FacetGrid(dfMetric, row='n_authors',  col="language", hue='model', height=3,palette="Set2")
g.map(plt.bar, "model", "f1").add_legend();

# %% [markdown]
# import pickle;
# with open("PANAA18.json","wb") as f:
#     pickle.dump(results,f)

# %%
def readGroundTruth():
    gt_train = [];
    gt_test = [];
    for problem in problems:
        _, train_labels, _, test_labels,_ = problemDoc(problem);
        gt_train.append(np.array(train_labels));
        gt_test.append(np.array(test_labels));
    return gt_train, gt_test;
groundTruthTrain, groundTruth = readGroundTruth()

# %%
data = PCA(2).fit(
    preprocessing.normalize(results['pos']['prob_train'][0])
).transform(
    preprocessing.normalize(results['char']['prob_test'][0])
);

# %%
plt.figure(figsize=(20,10))
for label in sorted(set(groundTruth[0])):
    _filter = groundTruth[0] ==label;
    plt.scatter(data[_filter,0],data[_filter,1], label=re.sub('\D+0+','',label),s=100)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True, shadow=True, ncol=int(len(set(groundTruth[0]))*0.50));

# %% [markdown]
# # mixed model

# %%
problemIndex = 0;
x_train = np.hstack([results[model]['prob_train'][problemIndex] for model in results])
x_test  = np.hstack([results[model]['prob_test'][problemIndex] for model in results])

# %%
results['char']['prob_test'][problemIndex].shape
# Out:
# (79, 20)

# %%
def plotPrediction(pred,labels):
    labels = np.array(labels);
    sortindex = np.argsort(labels);
    pred = pred/pred.max(axis=1).reshape(-1,1);
    pred = pred[sortindex];
    labels = labels[sortindex];
    plt.figure(figsize=(20,10))
    plt.grid(which='major')
    plt.imshow(pred.T,cmap=plt.cm.Blues);
    plt.xticks(range(len(labels)),[re.sub('\D+0+','',d) for d in labels]);
    plt.yticks(range(len(set(labels))),[re.sub('\D+0+','',d) for d in sorted(set(labels))]);
plotPrediction(results['char']['prob_test'][problemIndex], groundTruth[problemIndex])

# %%
data = PCA(2).fit(
    preprocessing.normalize(x_train)
).transform(
    preprocessing.normalize(x_test)
);

plt.figure(figsize=(20,10))
for label in sorted(set(groundTruth[0])):
    _filter = groundTruth[0] ==label;
    plt.scatter(data[_filter,0],data[_filter,1], label=re.sub('\D+0+','',label),s=100)
plt.legend(loc='upper center', bbox_to_anchor=(0.5, -0.05),
          fancybox=True, shadow=True, ncol=int(len(set(groundTruth[problemIndex]))*0.50));

# %%
pipelineFinal = Pipeline(steps=[
    #('normalization',preprocessing.MaxAbsScaler()),
    ('pca',PCA(0.9999)),
    ('clf', LogisticRegression(random_state=0,C=100000))
])

pipelineFinal.fit(x_train, groundTruthTrain[problemIndex]);
pred_label = pipelineFinal.predict(x_test);

# %%
f1_score(groundTruth[problemIndex],pred_label,average='macro')
# Out:
# 0.6083670033670032

# %%
plt.plot(pipelineFinal.steps[0][1].explained_variance_ratio_.cumsum())

# %%
def buildX(results,problemIndex, models):
    x_train = [results[model]['prob_train'][problemIndex] for model in models];
    x_test  = [results[model]['prob_test'][problemIndex] for model in models];
    
    x_train = [x for x in x_train if len(x) > 1];
    x_test  = [x for x in x_test  if len(x) > 1];
    
    if len(x_train) < 1:
        return None,None;
    
    return np.hstack(x_train), np.hstack(x_test);

def buildClassifier():
    return Pipeline(steps=[
                ('pca',PCA(0.9999)),
                ('clf', LogisticRegression(random_state=0,C=1))
            ])

def sortModels(results,problemIndex,models):
    f1 = [];
    
    for model in models:
        x_train, x_test = buildX(results, problemIndex, [model]);
        if x_train is None:
            f1.append(0); #dammit pl
        else:
            pipe = buildClassifier()
            pred_label = pipe.fit(x_train, groundTruthTrain[problemIndex]).predict(x_test);
            f1.append(f1_score(groundTruth[problemIndex],pred_label,average='macro'));
    models = np.array(models);
    f1 = np.array(f1);
    
    models = models[f1 >0];
    f1 = f1[f1 >0]
    
    return list(models[np.argsort(-f1)]);
    

resultFinal = []
bestModels = []
for problemIndex, problem in enumerate(problems):
    print('\n'+problem['problem']+' '+problem['language'])
    models = sortModels(results,problemIndex,list(results.keys()));
    print("sorted "+str(models))
    bestModel =[ models.pop(0)];
    x_train, x_test = buildX(results, problemIndex, bestModel);
    
    pipe = buildClassifier()

    pred_label = pipe.fit(x_train, groundTruthTrain[problemIndex]).predict(x_test);
    bestF1 = f1_score(groundTruth[problemIndex],pred_label,average='macro')
    
    models = list(set(models)-set(bestModel));
    
    improve = True;
    iteration = 0;
    while (improve):
        improve = False;
        iteration +=1 ;
        print("Iteration "+str(iteration)+" Best model:     %-75s %.4f"%(str(bestModel),bestF1))
        for model in models:
            currentModel = bestModel +[model];
            print("Iteration "+str(iteration)+" current model:  %-75s "%str(currentModel), end=' ')

            x_train, x_test = buildX(results, problemIndex, currentModel);

            pipe = buildClassifier()

            pred_label = pipe.fit(x_train, groundTruthTrain[problemIndex]).predict(x_test);
            currentF1 = f1_score(groundTruth[problemIndex],pred_label,average='macro');
            
            print(" %.4f"%currentF1)


            if currentF1/bestF1 > 1.015:
                improve = True;
                bestF1 = currentF1;
                bestModel = currentModel;
        models = list(set(models)-set(currentModel));
    print("Selected Model: "+str(bestModel))
    bestModels.append(bestModel);
    
    x_train, x_test = buildX(results, problemIndex, bestModel);
    
    pipelineFinal = Pipeline(steps=[
        ('pca',PCA(0.9999)),
        ('clf', LogisticRegression(random_state=0,C=100000))
    ])

    pipelineFinal.fit(x_train, groundTruthTrain[problemIndex]);
    pred_label = pipelineFinal.predict(x_test);
    resultFinal.append({
        'model':'0ensemble',
        'problem':problem['problem'],
        'language':problem['language'],
        'n_authors': len(set(groundTruthTrain[problemIndex])),
        'f1':round(f1_score(groundTruth[problemIndex],pred_label,average='macro'),3),
        'accuracy':round(accuracy_score(groundTruth[problemIndex],pred_label),3)
    })
# Out:
# problem00001 en
# sorted ['char', 'word', 'charFilter', 'tag', 'dist', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                    0.7564
# Iteration 1 current model:  ['char', 'tag']                                                               0.7302
# Iteration 1 current model:  ['char', 'dep']                                                               0.6724
# Iteration 1 current model:  ['char', 'pos']                                                               0.6586
# Iteration 1 current model:  ['char', 'charFilter']                                                        0.5796
# Iteration 1 current model:  ['char', 'word']                                                              0.6780
# Iteration 1 current model:  ['char', 'w2v']                                                               0.4897
# Iteration 1 current model:  ['char', 'dist']                                                              0.6611
# Selected Model: ['char']
#
# problem00002 en
# sorted ['char', 'word', 'tag', 'charFilter', 'pos', 'dist', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                    0.7264
# Iteration 1 current model:  ['char', 'tag']                                                               0.7117
# Iteration 1 current model:  ['char', 'dep']                                                               0.7667
# Iteration 1 current model:  ['char', 'dep', 'pos']                                                        0.7847
# Iteration 1 current model:  ['char', 'dep', 'pos', 'charFilter']                                          0.7637
# Iteration 1 current model:  ['char', 'dep', 'pos', 'word']                                                0.7745
# Iteration 1 current model:  ['char', 'dep', 'pos', 'w2v']                                                 0.6560
# Iteration 1 current model:  ['char', 'dep', 'pos', 'dist']                                                0.6976
# Iteration 2 Best model:     ['char', 'dep', 'pos']                                                      0.7847
# Iteration 2 current model:  ['char', 'dep', 'pos', 'word']                                                0.7745
# Iteration 2 current model:  ['char', 'dep', 'pos', 'w2v']                                                 0.6560
# Iteration 2 current model:  ['char', 'dep', 'pos', 'tag']                                                 0.7859
# Iteration 2 current model:  ['char', 'dep', 'pos', 'charFilter']                                          0.7637
# Selected Model: ['char', 'dep', 'pos']
#
# problem00003 en
# sorted ['char', 'charFilter', 'word', 'tag', 'pos', 'dep', 'dist', 'w2v']
# Iteration 1 Best model:     ['char']                                                                    0.8089
# Iteration 1 current model:  ['char', 'tag']                                                               0.7994
# Iteration 1 current model:  ['char', 'dep']                                                               0.7622
# Iteration 1 current model:  ['char', 'pos']                                                               0.6995
# Iteration 1 current model:  ['char', 'charFilter']                                                        0.7307
# Iteration 1 current model:  ['char', 'word']                                                              0.8719
# Iteration 1 current model:  ['char', 'word', 'w2v']                                                       0.5182
# Iteration 1 current model:  ['char', 'word', 'dist']                                                      0.7662
# Iteration 2 Best model:     ['char', 'word']                                                            0.8719
# Iteration 2 current model:  ['char', 'word', 'tag']                                                       0.7661
# Iteration 2 current model:  ['char', 'word', 'dep']                                                       0.7289
# Iteration 2 current model:  ['char', 'word', 'pos']                                                       0.7179
# Iteration 2 current model:  ['char', 'word', 'charFilter']                                                0.7937
# Iteration 2 current model:  ['char', 'word', 'w2v']                                                       0.5182
# Selected Model: ['char', 'word']
#
# problem00004 en
# sorted ['tag', 'pos', 'charFilter', 'char', 'dep', 'word', 'dist', 'w2v']
# Iteration 1 Best model:     ['tag']                                                                     0.8667
# Iteration 1 current model:  ['tag', 'word']                                                               0.8255
# Iteration 1 current model:  ['tag', 'dep']                                                                0.9179
# Iteration 1 current model:  ['tag', 'dep', 'pos']                                                         0.8333
# Iteration 1 current model:  ['tag', 'dep', 'charFilter']                                                  0.9179
# Iteration 1 current model:  ['tag', 'dep', 'char']                                                        0.8667
# Iteration 1 current model:  ['tag', 'dep', 'w2v']                                                         0.6889
# Iteration 1 current model:  ['tag', 'dep', 'dist']                                                        0.8357
# Iteration 2 Best model:     ['tag', 'dep']                                                              0.9179
# Iteration 2 current model:  ['tag', 'dep', 'word']                                                        0.8255
# Iteration 2 current model:  ['tag', 'dep', 'pos']                                                         0.8333
# Iteration 2 current model:  ['tag', 'dep', 'charFilter']                                                  0.9179
# Iteration 2 current model:  ['tag', 'dep', 'char']                                                        0.8667
# Iteration 2 current model:  ['tag', 'dep', 'w2v']                                                         0.6889
# Selected Model: ['tag', 'dep']
#
# problem00005 fr
# sorted ['char', 'dist', 'charFilter', 'word', 'pos', 'tag', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                    0.5571
# Iteration 1 current model:  ['char', 'tag']                                                               0.5879
# Iteration 1 current model:  ['char', 'tag', 'dep']                                                        0.5959
# Iteration 1 current model:  ['char', 'tag', 'pos']                                                        0.5674
# Iteration 1 current model:  ['char', 'tag', 'charFilter']                                                 0.5991
# Iteration 1 current model:  ['char', 'tag', 'charFilter', 'word']                                         0.5952
# Iteration 1 current model:  ['char', 'tag', 'charFilter', 'w2v']                                          0.5200
# Iteration 1 current model:  ['char', 'tag', 'charFilter', 'dist']                                         0.6074
# Iteration 2 Best model:     ['char', 'tag', 'charFilter']                                               0.5991
# Iteration 2 current model:  ['char', 'tag', 'charFilter', 'pos']                                          0.5569
# Iteration 2 current model:  ['char', 'tag', 'charFilter', 'w2v']                                          0.5200
# Iteration 2 current model:  ['char', 'tag', 'charFilter', 'word']                                         0.5952
# Iteration 2 current model:  ['char', 'tag', 'charFilter', 'dep']                                          0.5987
# Selected Model: ['char', 'tag', 'charFilter']
#
# problem00006 fr
# sorted ['char', 'word', 'dist', 'tag', 'charFilter', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                    0.6807
# Iteration 1 current model:  ['char', 'tag']                                                               0.7043
# Iteration 1 current model:  ['char', 'tag', 'dep']                                                        0.6352
# Iteration 1 current model:  ['char', 'tag', 'pos']                                                        0.6939
# Iteration 1 current model:  ['char', 'tag', 'charFilter']                                                 0.5844
# Iteration 1 current model:  ['char', 'tag', 'word']                                                       0.6991
# Iteration 1 current model:  ['char', 'tag', 'w2v']                                                        0.4932
# Iteration 1 current model:  ['char', 'tag', 'dist']                                                       0.6385
# Iteration 2 Best model:     ['char', 'tag']                                                             0.7043
# Iteration 2 current model:  ['char', 'tag', 'dep']                                                        0.6352
# Iteration 2 current model:  ['char', 'tag', 'pos']                                                        0.6939
# Iteration 2 current model:  ['char', 'tag', 'charFilter']                                                 0.5844
# Iteration 2 current model:  ['char', 'tag', 'word']                                                       0.6991
# Iteration 2 current model:  ['char', 'tag', 'w2v']                                                        0.4932
# Selected Model: ['char', 'tag']
#
# problem00007 fr
# sorted ['tag', 'pos', 'char', 'word', 'dist', 'charFilter', 'dep', 'w2v']
# Iteration 1 Best model:     ['tag']                                                                     0.6801
# Iteration 1 current model:  ['tag', 'word']                                                               0.6820
# Iteration 1 current model:  ['tag', 'dep']                                                                0.6253
# Iteration 1 current model:  ['tag', 'pos']                                                                0.6463
# Iteration 1 current model:  ['tag', 'charFilter']                                                         0.7455
# Iteration 1 current model:  ['tag', 'charFilter', 'char']                                                 0.7256
# Iteration 1 current model:  ['tag', 'charFilter', 'w2v']                                                  0.3643
# Iteration 1 current model:  ['tag', 'charFilter', 'dist']                                                 0.7132
# Iteration 2 Best model:     ['tag', 'charFilter']                                                       0.7455
# Iteration 2 current model:  ['tag', 'charFilter', 'word']                                                 0.6497
# Iteration 2 current model:  ['tag', 'charFilter', 'dep']                                                  0.7370
# Iteration 2 current model:  ['tag', 'charFilter', 'pos']                                                  0.7632
# Iteration 2 current model:  ['tag', 'charFilter', 'pos', 'char']                                          0.7370
# Iteration 2 current model:  ['tag', 'charFilter', 'pos', 'w2v']                                           0.5120
# Iteration 3 Best model:     ['tag', 'charFilter', 'pos']                                                0.7632
# Iteration 3 current model:  ['tag', 'charFilter', 'pos', 'char']                                          0.7370
# Iteration 3 current model:  ['tag', 'charFilter', 'pos', 'word']                                          0.7888
# Iteration 3 current model:  ['tag', 'charFilter', 'pos', 'word', 'dep']                                   0.8205
# Iteration 4 Best model:     ['tag', 'charFilter', 'pos', 'word', 'dep']                                 0.8205
# Iteration 4 current model:  ['tag', 'charFilter', 'pos', 'word', 'dep', 'char']                           0.7455
# Selected Model: ['tag', 'charFilter', 'pos', 'word', 'dep']
#
# problem00008 fr
# sorted ['tag', 'char', 'charFilter', 'pos', 'word', 'dist', 'dep', 'w2v']
# Iteration 1 Best model:     ['tag']                                                                     0.7905
# Iteration 1 current model:  ['tag', 'dep']                                                                0.6374
# Iteration 1 current model:  ['tag', 'char']                                                               0.7074
# Iteration 1 current model:  ['tag', 'pos']                                                                0.7905
# Iteration 1 current model:  ['tag', 'charFilter']                                                         0.7074
# Iteration 1 current model:  ['tag', 'word']                                                               0.7228
# Iteration 1 current model:  ['tag', 'w2v']                                                                0.2980
# Iteration 1 current model:  ['tag', 'dist']                                                               0.5980
# Selected Model: ['tag']
#
# problem00009 it
# sorted ['char', 'charFilter', 'dist', 'tag', 'word', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                    0.6738
# Iteration 1 current model:  ['char', 'tag']                                                               0.6542
# Iteration 1 current model:  ['char', 'dep']                                                               0.6663
# Iteration 1 current model:  ['char', 'pos']                                                               0.5873
# Iteration 1 current model:  ['char', 'charFilter']                                                        0.6464
# Iteration 1 current model:  ['char', 'word']                                                              0.6791
# Iteration 1 current model:  ['char', 'w2v']                                                               0.4422
# Iteration 1 current model:  ['char', 'dist']                                                              0.6546
# Selected Model: ['char']
#
# problem00010 it
# sorted ['char', 'dist', 'charFilter', 'tag', 'word', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                    0.6808
# Iteration 1 current model:  ['char', 'tag']                                                               0.6302
# Iteration 1 current model:  ['char', 'dep']                                                               0.5859
# Iteration 1 current model:  ['char', 'pos']                                                               0.5583
# Iteration 1 current model:  ['char', 'charFilter']                                                        0.5941
# Iteration 1 current model:  ['char', 'word']                                                              0.6701
# Iteration 1 current model:  ['char', 'w2v']                                                               0.4679
# Iteration 1 current model:  ['char', 'dist']                                                              0.7015
# Iteration 2 Best model:     ['char', 'dist']                                                            0.7015
# Iteration 2 current model:  ['char', 'dist', 'tag']                                                       0.6981
# Iteration 2 current model:  ['char', 'dist', 'dep']                                                       0.7015
# Iteration 2 current model:  ['char', 'dist', 'pos']                                                       0.6744
# Iteration 2 current model:  ['char', 'dist', 'charFilter']                                                0.6730
# Iteration 2 current model:  ['char', 'dist', 'word']                                                      0.7001
# Iteration 2 current model:  ['char', 'dist', 'w2v']                                                       0.6732
# Selected Model: ['char', 'dist']
#
# problem00011 it
# sorted ['char', 'dist', 'word', 'charFilter', 'tag', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                    0.7775
# Iteration 1 current model:  ['char', 'tag']                                                               0.7742
# Iteration 1 current model:  ['char', 'dep']                                                               0.7775
# Iteration 1 current model:  ['char', 'pos']                                                               0.8517
# Iteration 1 current model:  ['char', 'pos', 'charFilter']                                                 0.8409
# Iteration 1 current model:  ['char', 'pos', 'word']                                                       0.7775
# Iteration 1 current model:  ['char', 'pos', 'w2v']                                                        0.5025
# Iteration 1 current model:  ['char', 'pos', 'dist']                                                       0.7618
# Iteration 2 Best model:     ['char', 'pos']                                                             0.8517
# Iteration 2 current model:  ['char', 'pos', 'tag']                                                        0.7644
# Iteration 2 current model:  ['char', 'pos', 'dep']                                                        0.8075
# Iteration 2 current model:  ['char', 'pos', 'charFilter']                                                 0.8409
# Iteration 2 current model:  ['char', 'pos', 'word']                                                       0.7775
# Iteration 2 current model:  ['char', 'pos', 'w2v']                                                        0.5025
# Selected Model: ['char', 'pos']
#
# problem00012 it
# sorted ['char', 'word', 'charFilter', 'dist', 'pos', 'dep', 'tag', 'w2v']
# Iteration 1 Best model:     ['char']                                                                    0.5378
# Iteration 1 current model:  ['char', 'tag']                                                               0.5034
# Iteration 1 current model:  ['char', 'dep']                                                               0.5480
# Iteration 1 current model:  ['char', 'dep', 'pos']                                                        0.5166
# Iteration 1 current model:  ['char', 'dep', 'charFilter']                                                 0.5292
# Iteration 1 current model:  ['char', 'dep', 'word']                                                       0.5235
# Iteration 1 current model:  ['char', 'dep', 'w2v']                                                        0.2098
# Iteration 1 current model:  ['char', 'dep', 'dist']                                                       0.5393
# Iteration 2 Best model:     ['char', 'dep']                                                             0.5480
# Iteration 2 current model:  ['char', 'dep', 'tag']                                                        0.5087
# Iteration 2 current model:  ['char', 'dep', 'pos']                                                        0.5166
# Iteration 2 current model:  ['char', 'dep', 'charFilter']                                                 0.5292
# Iteration 2 current model:  ['char', 'dep', 'word']                                                       0.5235
# Iteration 2 current model:  ['char', 'dep', 'w2v']                                                        0.2098
# Selected Model: ['char', 'dep']
#
# problem00013 pl
# sorted ['char', 'word', 'dist', 'w2v']
# Iteration 1 Best model:     ['char']                                                                    0.5174
# Iteration 1 current model:  ['char', 'word']                                                              0.4591
# Iteration 1 current model:  ['char', 'w2v']                                                               0.5324
# Iteration 1 current model:  ['char', 'w2v', 'dist']                                                       0.4623
# Iteration 2 Best model:     ['char', 'w2v']                                                             0.5324
# Iteration 2 current model:  ['char', 'w2v', 'word']                                                       0.4634
# Selected Model: ['char', 'w2v']
#
# problem00014 pl
# sorted ['char', 'word', 'dist', 'w2v']
# Iteration 1 Best model:     ['char']                                                                    0.5079
# Iteration 1 current model:  ['char', 'word']                                                              0.4971
# Iteration 1 current model:  ['char', 'w2v']                                                               0.5044
# Iteration 1 current model:  ['char', 'dist']                                                              0.4965
# Selected Model: ['char']
#
# problem00015 pl
# sorted ['word', 'char', 'dist', 'w2v']
# Iteration 1 Best model:     ['word']                                                                    0.3417
# Iteration 1 current model:  ['word', 'char']                                                              0.4269
# Iteration 1 current model:  ['word', 'char', 'w2v']                                                       0.3717
# Iteration 1 current model:  ['word', 'char', 'dist']                                                      0.3547
# Iteration 2 Best model:     ['word', 'char']                                                            0.4269
# Iteration 2 current model:  ['word', 'char', 'w2v']                                                       0.3717
# Selected Model: ['word', 'char']
#
# problem00016 pl
# sorted ['word', 'dist', 'char', 'w2v']
# Iteration 1 Best model:     ['word']                                                                    0.4230
# Iteration 1 current model:  ['word', 'char']                                                              0.4197
# Iteration 1 current model:  ['word', 'w2v']                                                               0.4219
# Iteration 1 current model:  ['word', 'dist']                                                              0.4271
# Selected Model: ['word']
#
# problem00017 sp
# sorted ['dist', 'char', 'charFilter', 'word', 'tag', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['dist']                                                                    0.6807
# Iteration 1 current model:  ['dist', 'tag']                                                               0.7277
# Iteration 1 current model:  ['dist', 'tag', 'dep']                                                        0.7514
# Iteration 1 current model:  ['dist', 'tag', 'dep', 'char']                                                0.8111
# Iteration 1 current model:  ['dist', 'tag', 'dep', 'char', 'pos']                                         0.8090
# Iteration 1 current model:  ['dist', 'tag', 'dep', 'char', 'charFilter']                                  0.7724
# Iteration 1 current model:  ['dist', 'tag', 'dep', 'char', 'word']                                        0.8100
# Iteration 1 current model:  ['dist', 'tag', 'dep', 'char', 'w2v']                                         0.7621
# Iteration 2 Best model:     ['dist', 'tag', 'dep', 'char']                                              0.8111
# Iteration 2 current model:  ['dist', 'tag', 'dep', 'char', 'word']                                        0.8100
# Iteration 2 current model:  ['dist', 'tag', 'dep', 'char', 'pos']                                         0.8090
# Iteration 2 current model:  ['dist', 'tag', 'dep', 'char', 'charFilter']                                  0.7724
# Selected Model: ['dist', 'tag', 'dep', 'char']
#
# problem00018 sp
# sorted ['char', 'dist', 'charFilter', 'word', 'tag', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['char']                                                                    0.7499
# Iteration 1 current model:  ['char', 'tag']                                                               0.8009
# Iteration 1 current model:  ['char', 'tag', 'dep']                                                        0.7699
# Iteration 1 current model:  ['char', 'tag', 'pos']                                                        0.7698
# Iteration 1 current model:  ['char', 'tag', 'charFilter']                                                 0.7597
# Iteration 1 current model:  ['char', 'tag', 'word']                                                       0.8286
# Iteration 1 current model:  ['char', 'tag', 'word', 'w2v']                                                0.6905
# Iteration 1 current model:  ['char', 'tag', 'word', 'dist']                                               0.8810
# Iteration 2 Best model:     ['char', 'tag', 'word', 'dist']                                             0.8810
# Iteration 2 current model:  ['char', 'tag', 'word', 'dist', 'pos']                                        0.8960
# Iteration 2 current model:  ['char', 'tag', 'word', 'dist', 'pos', 'w2v']                                 0.8421
# Iteration 2 current model:  ['char', 'tag', 'word', 'dist', 'pos', 'charFilter']                          0.8693
# Iteration 2 current model:  ['char', 'tag', 'word', 'dist', 'pos', 'dep']                                 0.8960
# Iteration 3 Best model:     ['char', 'tag', 'word', 'dist', 'pos']                                      0.8960
# Iteration 3 current model:  ['char', 'tag', 'word', 'dist', 'pos', 'w2v']                                 0.8421
# Iteration 3 current model:  ['char', 'tag', 'word', 'dist', 'pos', 'charFilter']                          0.8693
# Selected Model: ['char', 'tag', 'word', 'dist', 'pos']
#
# problem00019 sp
# sorted ['charFilter', 'dist', 'char', 'word', 'tag', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['charFilter']                                                              0.7688
# Iteration 1 current model:  ['charFilter', 'tag']                                                         0.8010
# Iteration 1 current model:  ['charFilter', 'tag', 'dep']                                                  0.7777
# Iteration 1 current model:  ['charFilter', 'tag', 'char']                                                 0.8200
# Iteration 1 current model:  ['charFilter', 'tag', 'char', 'pos']                                          0.8010
# Iteration 1 current model:  ['charFilter', 'tag', 'char', 'word']                                         0.8200
# Iteration 1 current model:  ['charFilter', 'tag', 'char', 'w2v']                                          0.8200
# Iteration 1 current model:  ['charFilter', 'tag', 'char', 'dist']                                         0.8109
# Iteration 2 Best model:     ['charFilter', 'tag', 'char']                                               0.8200
# Iteration 2 current model:  ['charFilter', 'tag', 'char', 'w2v']                                          0.8200
# Iteration 2 current model:  ['charFilter', 'tag', 'char', 'word']                                         0.8200
# Iteration 2 current model:  ['charFilter', 'tag', 'char', 'pos']                                          0.8010
# Iteration 2 current model:  ['charFilter', 'tag', 'char', 'dep']                                          0.7966
# Selected Model: ['charFilter', 'tag', 'char']
#
# problem00020 sp
# sorted ['dist', 'tag', 'charFilter', 'char', 'word', 'pos', 'dep', 'w2v']
# Iteration 1 Best model:     ['dist']                                                                    0.8963
# Iteration 1 current model:  ['dist', 'tag']                                                               0.8963
# Iteration 1 current model:  ['dist', 'dep']                                                               0.8788
# Iteration 1 current model:  ['dist', 'char']                                                              0.7501
# Iteration 1 current model:  ['dist', 'pos']                                                               0.8963
# Iteration 1 current model:  ['dist', 'charFilter']                                                        0.7905
# Iteration 1 current model:  ['dist', 'word']                                                              0.9143
# Iteration 1 current model:  ['dist', 'word', 'w2v']                                                       0.7709
# Iteration 2 Best model:     ['dist', 'word']                                                            0.9143
# Iteration 2 current model:  ['dist', 'word', 'tag']                                                       0.9332
# Iteration 2 current model:  ['dist', 'word', 'tag', 'dep']                                                0.9332
# Iteration 2 current model:  ['dist', 'word', 'tag', 'pos']                                                0.9332
# Iteration 2 current model:  ['dist', 'word', 'tag', 'charFilter']                                         0.8963
# Iteration 2 current model:  ['dist', 'word', 'tag', 'char']                                               0.8616
# Iteration 3 Best model:     ['dist', 'word', 'tag']                                                     0.9332
# Iteration 3 current model:  ['dist', 'word', 'tag', 'pos']                                                0.9332
# Iteration 3 current model:  ['dist', 'word', 'tag', 'charFilter']                                         0.8963
# Iteration 3 current model:  ['dist', 'word', 'tag', 'dep']                                                0.9332
# Selected Model: ['dist', 'word', 'tag']

# %%
pd.concat([dfMetric, pd.DataFrame(resultFinal)]) \
    .pivot(index='problem',columns='model',values=['f1','accuracy']).fillna(value=0)\
    .style.background_gradient(subset=['f1'], axis=1, cmap=plt.cm.Blues)\
    .background_gradient(subset=['accuracy'], axis=1, cmap=plt.cm.Greens)
# Out:
# <style  type="text/css" >
#     #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col2 {
#             background-color:  #8dc1dd;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col3 {
#             background-color:  #d5e5f4;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col4 {
#             background-color:  #c2d9ee;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col5 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col6 {
#             background-color:  #a8cee4;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col8 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col9 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col10 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col11 {
#             background-color:  #3fa95c;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col12 {
#             background-color:  #b4e1ad;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col13 {
#             background-color:  #bce4b5;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col14 {
#             background-color:  #8ed08b;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col15 {
#             background-color:  #62bb6d;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col16 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row0_col17 {
#             background-color:  #39a257;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col1 {
#             background-color:  #0f5aa3;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col2 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col3 {
#             background-color:  #e7f0fa;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col4 {
#             background-color:  #d2e3f3;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col5 {
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col6 {
#             background-color:  #95c5df;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col8 {
#             background-color:  #529dcc;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col9 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col10 {
#             background-color:  #004d1f;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col11 {
#             background-color:  #52b365;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col12 {
#             background-color:  #dcf2d7;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col13 {
#             background-color:  #bbe4b4;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col14 {
#             background-color:  #84cc83;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col15 {
#             background-color:  #79c67a;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col16 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row1_col17 {
#             background-color:  #45ad5f;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col1 {
#             background-color:  #09529d;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col2 {
#             background-color:  #4b98ca;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col3 {
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col4 {
#             background-color:  #a9cfe5;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col5 {
#             background-color:  #a8cee4;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col6 {
#             background-color:  #77b5d9;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col7 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col8 {
#             background-color:  #60a7d2;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col9 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col10 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col11 {
#             background-color:  #127c39;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col12 {
#             background-color:  #c8e9c1;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col13 {
#             background-color:  #75c477;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col14 {
#             background-color:  #a0d99b;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col15 {
#             background-color:  #40aa5d;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col16 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row2_col17 {
#             background-color:  #319a50;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row3_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row3_col1 {
#             background-color:  #135fa7;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row3_col2 {
#             background-color:  #125ea6;
#             color:  #f1f1f1;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row3_col3 {
#             background-color:  #2a7ab9;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row3_col4 {
#             background-color:  #cee0f2;
#             color:  #000000;
#         }    #T_4123b828_2f32_11e9_a842_8c8590360b07row3_col5 {
#             background-color:  #125ea6;

# %%
for problemIndex, problem in enumerate(problems):
    print(problem['problem'] +' '+problem['language']+' '+ str(bestModels[problemIndex]))
# Out:
# problem00001 en ['char']
# problem00002 en ['char', 'dep', 'pos']
# problem00003 en ['char', 'word']
# problem00004 en ['tag', 'dep']
# problem00005 fr ['char', 'tag', 'charFilter']
# problem00006 fr ['char', 'tag']
# problem00007 fr ['tag', 'charFilter', 'pos', 'word', 'dep']
# problem00008 fr ['tag']
# problem00009 it ['char']
# problem00010 it ['char', 'dist']
# problem00011 it ['char', 'pos']
# problem00012 it ['char', 'dep']
# problem00013 pl ['char', 'w2v']
# problem00014 pl ['char']
# problem00015 pl ['word', 'char']
# problem00016 pl ['word']
# problem00017 sp ['dist', 'tag', 'dep', 'char']
# problem00018 sp ['char', 'tag', 'word', 'dist', 'pos']
# problem00019 sp ['charFilter', 'tag', 'char']
# problem00020 sp ['dist', 'word', 'tag']

# %%
pd.pivot_table(
    pd.concat([dfMetric, pd.DataFrame(resultFinal)]),
    index='model',
    columns='n_authors',
    values='f1',
    aggfunc='mean',
    fill_value=0).T
# Out:
# model      0ensemble   char  charFilter    dep   dist    pos    tag    w2v  \
# n_authors
# 5             0.7224 0.6256      0.6640 0.5142 0.5734 0.6278 0.7037 0.2006
# 10            0.7582 0.6494      0.6583 0.4400 0.5600 0.5660 0.6300 0.1690
# 15            0.7190 0.6692      0.5453 0.3377 0.5190 0.4547 0.5385 0.1810
# 20            0.6716 0.6308      0.5507 0.3273 0.5010 0.4173 0.4825 0.1520
#
# model       word
# n_authors
# 5         0.5614
# 10        0.5798
# 15        0.5088
# 20        0.4910

# %%
pd.pivot_table(
    pd.concat([dfMetric, pd.DataFrame(resultFinal)]),
    index='model',
    columns='language',
    values='f1',
    aggfunc='mean',
    fill_value=0)
# Out:
# language       en     fr     it     pl     sp
# model
# 0ensemble  0.8327 0.7282 0.6940 0.4690 0.8650
# char       0.7802 0.6385 0.6678 0.4353 0.6970
# charFilter 0.6392 0.5380 0.5660 0.0000 0.6750
# dep        0.5423 0.3410 0.3087 0.0000 0.4273
# dist       0.5032 0.5022 0.5930 0.3393 0.7540
# pos        0.5882 0.5613 0.3717 0.0000 0.5445
# tag        0.6298 0.5940 0.4765 0.0000 0.6545
# w2v        0.3905 0.1430 0.1055 0.0785 0.1608
# word       0.6150 0.5312 0.5345 0.3745 0.6210

# %%
pd.pivot_table(
    pd.concat([dfMetric, pd.DataFrame(resultFinal)]),
    index='model',
    columns=['language','n_authors'],
    values='f1',
    aggfunc='mean',
    fill_value=0).style.background_gradient(axis=0, cmap=plt.cm.Blues)
# Out:
# <style  type="text/css" >
#     #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col7 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col8 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col9 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col10 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col12 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col13 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col14 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col15 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col16 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col17 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col18 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row0_col19 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col0 {
#             background-color:  #135fa7;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col1 {
#             background-color:  #09529d;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col2 {
#             background-color:  #0f5aa3;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col4 {
#             background-color:  #09529d;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col5 {
#             background-color:  #2c7cba;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col6 {
#             background-color:  #083a7a;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col7 {
#             background-color:  #084a91;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col8 {
#             background-color:  #083573;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col9 {
#             background-color:  #084a91;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col10 {
#             background-color:  #083979;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col11 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col12 {
#             background-color:  #084d96;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col13 {
#             background-color:  #1865ac;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col14 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col15 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col16 {
#             background-color:  #4695c8;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col17 {
#             background-color:  #115ca5;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col18 {
#             background-color:  #1460a8;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row1_col19 {
#             background-color:  #1a68ae;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col0 {
#             background-color:  #125ea6;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col1 {
#             background-color:  #4b98ca;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col2 {
#             background-color:  #a6cee4;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col3 {
#             background-color:  #8dc1dd;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col4 {
#             background-color:  #09529d;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col5 {
#             background-color:  #5da5d1;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col6 {
#             background-color:  #4e9acb;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col7 {
#             background-color:  #2a7ab9;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col8 {
#             background-color:  #2070b4;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col9 {
#             background-color:  #1764ab;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col10 {
#             background-color:  #3181bd;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col11 {
#             background-color:  #084f99;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col12 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col13 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col14 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col15 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col16 {
#             background-color:  #4493c7;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col17 {
#             background-color:  #08458a;
#             color:  #f1f1f1;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col18 {
#             background-color:  #3a8ac2;
#             color:  #000000;
#         }    #T_0a4f380c_2f32_11e9_8953_8c8590360b07row2_col19 {
#             background-color:  #2272b6;
